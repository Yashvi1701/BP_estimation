# %% [markdown]
# ## Windkessel-Informed Neural Network for Cuffless BP Estimation
# ==========================================================================
#
# Physics constraint: 2-element Windkessel diastolic decay equation
#  ##   DBP = SBP * exp(-decay_time / RC) ##
#
# This constrains DBP to be consistent with the model's own SBP prediction
# and the measured diastolic decay time (systolic peak -> dicrotic notch).
# SBP remains purely data-driven (see explanation in accompanying chat message).
#
# Sections:
#
#     -  Peak / dicrotic notch detection  (feature extraction from raw PPG)
#
#     -  RC estimation                    (fit once from training data)
#
#     -  Windkessel physics loss          (the actual PINN constraint)
#
#     - Model architecture               (simple 1D CNN)
#
#     - Training loop                    (combines data loss + physics loss)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from scipy.signal import (
    find_peaks,
    savgol_filter
)
import h5py

from tqdm import tqdm
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

from torch.utils.data import Dataset, DataLoader

import sys
sys.path.append("..") 

device = torch.device(
    "cuda" if torch.cuda.is_available()
    else "cpu"
)

print(device)
# Out:
# cuda

# %% [markdown]
# ## Peak / Dicrotic Notch detection ##

# %% [markdown]
# Systolic peak = start of the "pressure is falling" phase, and dicrotic notch = the precise physiological start of diastole, where the heart is no longer pushing anything in.
#
# For this eqn - P(t) = P_sys · exp(-t / RC)
#
# We need t = decay time, which is simply the number of seconds it takes for arterial pressure to go from its systolic peak down to the start of the diastolic (passive) phase, measured as the time gap between the systolic peak and the dicrotic notch on the PPG waveform.

# %%
from models.PINN import get_systolic_peak,calculate_derivatives, get_dicrotic_notch, extract_delay_times, get_delay_time, prepare_UCI_dataset, estimate_RC, grid_search_RC

# %%
FS = 125
WINDOW_SIZE = 1000

MAT_PATH = "/data1/yashvi_bhuva/BP_estimation_using_PPG/UCI/wavelets_data/Part_1.mat"
f = h5py.File(MAT_PATH, "r")

dataset = f["Part_1"]

# print("Number of recordings:", dataset.shape[0])
ref = dataset[1,0 ]

recording = f[ref][:]

print("Recording shape:", recording.shape)
ppg = recording[:, 0]
abp = recording[:, 1]

print("PPG length:", len(ppg))
print("ABP length:", len(abp))
ppg_std = np.std(ppg)


ppg = (ppg - np.mean(ppg)) / ppg_std # Normalize PPG signal
START = 0

ppg_window = ppg[
    START:START + WINDOW_SIZE
]

print("Window shape:", ppg_window.shape)


# ==========================================
# Detect ALL systolic peaks
# ==========================================

sys_peaks = get_systolic_peak(
    ppg_window,
    FS
)

print(
    "Number of systolic peaks:",
    len(sys_peaks)
)

print(
    "Systolic peak indices:",
    sys_peaks
)


# ==========================================
# Find notch after EACH systolic peak
# ==========================================

notches = []

for sys_idx in sys_peaks:

    notch_idx = get_dicrotic_notch(
        ppg_window,
        sys_idx,
        FS
    )

    notches.append(notch_idx)


# ==========================================
# Print results
# ==========================================

print("\nDetected landmarks:")

for i, (sys_idx, notch_idx) in enumerate(
    zip(sys_peaks, notches)
):

    print(
        f"Beat {i+1}: "
        f"Systolic = {sys_idx} "
        f"({sys_idx / FS:.3f} s), "
        f"Notch = {notch_idx}"
    )


delay_times = []

for sys_idx, notch_idx in zip(
    sys_peaks,
    notches
):

    if notch_idx is None:
        delay_times.append(np.nan)

    else:

        delay = (
            notch_idx - sys_idx
        ) / FS

        delay_times.append(delay)


delay_times = np.array(
    delay_times,
    dtype=np.float32
)


print("\nPeak → notch delays:")

for i, delay in enumerate(delay_times):

    if np.isnan(delay):

        print(
            f"Beat {i+1}: Detection failed"
        )

    else:

        print(
            f"Beat {i+1}: "
            f"{delay:.3f} seconds"
        )
# Out:
# Recording shape: (61000, 3)
# PPG length: 61000
# ABP length: 61000
# Window shape: (1000,)
# Number of systolic peaks: 15
# Systolic peak indices: [ 54 119 184 249 312 377 442 507 569 633 698 761 824 886 950]
#
# Detected landmarks:
# Beat 1: Systolic = 54 (0.432 s), Notch = 74
# Beat 2: Systolic = 119 (0.952 s), Notch = 138
# Beat 3: Systolic = 184 (1.472 s), Notch = 203
# Beat 4: Systolic = 249 (1.992 s), Notch = 267
# Beat 5: Systolic = 312 (2.496 s), Notch = 333
# Beat 6: Systolic = 377 (3.016 s), Notch = 397
# Beat 7: Systolic = 442 (3.536 s), Notch = 461
# Beat 8: Systolic = 507 (4.056 s), Notch = 526
# Beat 9: Systolic = 569 (4.552 s), Notch = 588
# Beat 10: Systolic = 633 (5.064 s), Notch = 652
# Beat 11: Systolic = 698 (5.584 s), Notch = 716
# Beat 12: Systolic = 761 (6.088 s), Notch = 783
# Beat 13: Systolic = 824 (6.592 s), Notch = 844
# Beat 14: Systolic = 886 (7.088 s), Notch = 907
# Beat 15: Systolic = 950 (7.600 s), Notch = 970
#
# Peak → notch delays:
# Beat 1: 0.160 seconds
# Beat 2: 0.152 seconds
# Beat 3: 0.152 seconds
# Beat 4: 0.144 seconds
# Beat 5: 0.168 seconds
# Beat 6: 0.160 seconds
# Beat 7: 0.152 seconds
# Beat 8: 0.152 seconds
# Beat 9: 0.152 seconds
# Beat 10: 0.152 seconds
# Beat 11: 0.144 seconds
# Beat 12: 0.176 seconds
# Beat 13: 0.160 seconds
# Beat 14: 0.168 seconds
# Beat 15: 0.160 seconds

# %%
smooth_ppg = savgol_filter(
    ppg_window,
    window_length=21,
    polyorder=3
)
vpg = np.gradient(smooth_ppg) * FS
apg = np.gradient(vpg) * FS


time = np.arange(
    len(ppg_window)
) / FS

fig, axes = plt.subplots(
    3,
    1,
    figsize=(15, 10),
    sharex=True
)


# ==================================================
# PPG
# ==================================================

axes[0].plot(
    time,
    ppg_window,
    alpha=0.4,
    label="PPG"
)

axes[0].plot(
    time,
    smooth_ppg,
    label="Smoothed PPG"
)


# All systolic peaks

axes[0].scatter(
    sys_peaks / FS,
    smooth_ppg[sys_peaks],
    s=80,
    label="Systolic peaks"
)


# All detected notches

valid_notches = [
    n for n in notches
    if n is not None
]

if len(valid_notches) > 0:

    valid_notches = np.array(
        valid_notches,
        dtype=int
    )

    axes[0].scatter(
        valid_notches / FS,
        smooth_ppg[valid_notches],
        s=100,
        label="Estimated notches"
    )


axes[0].set_ylabel("PPG")
axes[0].legend()
axes[0].grid()


# ==================================================
# VPG
# ==================================================

axes[1].plot(
    time,
    vpg,
    label="VPG"
)

axes[1].set_ylabel("VPG")
axes[1].legend()
axes[1].grid()


# ==================================================
# APG
# ==================================================

axes[2].plot(
    time,
    apg,
    label="APG"
)

axes[2].set_xlabel("Time (seconds)")
axes[2].set_ylabel("APG")
axes[2].legend()
axes[2].grid()


plt.tight_layout()
plt.show()

# %%
delay_time =  get_delay_time(ppg_window)
print(delay_time)
# Out:
# [0.16  0.152 0.152 0.144 0.168 0.16  0.152 0.152 0.152 0.152 0.144 0.176
#  0.16  0.168 0.16 ]

# %%
DATA_PATH = (
    "/data1/yashvi_bhuva/"
    "BP_estimation_using_PPG/UCI/wavelets_data")
X_train, y_train, delay_train, X_val, y_val, delay_val, X_test, y_test, delay_test = prepare_UCI_dataset(
    data_path=DATA_PATH)
# Out:
# Total recordings: 12000
# Train recordings: 8400
# Validation recordings: 1200
# Test recordings: 2400
#
# Processing TRAIN recordings...
# Processing recordings: 100%|██████████| 8400/8400 [38:11<00:00,  3.67it/s]
# Skipped recordings: 4
#
# Processing VALIDATION recordings...
# Processing recordings: 100%|██████████| 1200/1200 [05:29<00:00,  3.64it/s]
# Skipped recordings: 0
#
# Processing TEST recordings...
# Processing recordings: 100%|██████████| 2400/2400 [11:09<00:00,  3.59it/s]
# Skipped recordings: 1
#
# ======================================
# DATASET SHAPES
# ======================================
# X_train: torch.Size([455001, 1, 1000])
# y_train: torch.Size([455001, 2])
# delay_train: torch.Size([455001])
# X_val: torch.Size([65488, 1, 1000])
# y_val: torch.Size([65488, 2])
# delay_val: torch.Size([65488])
# X_test: torch.Size([133602, 1, 1000])
# y_test: torch.Size([133602, 2])
# delay_test: torch.Size([133602])

# %%
print("Shape:", delay_train.shape)
print("Dtype:", delay_train.dtype)
print("NaN count:", np.isnan(delay_train).sum())
delay_train_np = delay_train.detach().cpu().numpy().astype(np.float32)
print(
    "NaN percentage:",
    100 * np.isnan(delay_train_np).mean(),
    "%"
)

valid_delay = delay_train_np[
    np.isfinite(delay_train_np)
]

print("Valid values:", len(valid_delay))

if len(valid_delay) > 0:

    print("\nStatistics:")

    print(
        "Min    :",
        np.min(valid_delay)
    )

    print(
        "Max    :",
        np.max(valid_delay)
    )

    print(
        "Mean   :",
        np.mean(valid_delay)
    )

    print(
        "Median :",
        np.median(valid_delay)
    )

    print(
        "Std    :",
        np.std(valid_delay)
    )

if len(valid_delay) > 0:

    print("\nRange checks:")

    print(
        "Below 0.08 s:",
        np.sum(valid_delay < 0.08)
    )

    print(
        "Above 0.35 s:",
        np.sum(valid_delay > 0.35)
    )

    print(
        "Within 0.08–0.35 s:",
        np.sum(
            (valid_delay >= 0.08) &
            (valid_delay <= 0.35)
        )
    )


if len(valid_delay) > 0:

    print("\nPercentiles:")

    for p in [1, 5, 25, 50, 75, 95, 99]:

        print(
            f"{p:2d}% :",
            np.percentile(valid_delay, p)
        )
# Out:
# Shape: torch.Size([455001])
# Dtype: torch.float32
# NaN count: tensor(0)
# NaN percentage: 0.0 %
# Valid values: 455001
#
# Statistics:
# Min    : 0.088
# Max    : 0.336
# Mean   : 0.18087102
# Median : 0.176
# Std    : 0.036806032
#
# Range checks:
# Below 0.08 s: 0
# Above 0.35 s: 0
# Within 0.08–0.35 s: 455001
#
# Percentiles:
#  1% : 0.112
#  5% : 0.128
# 25% : 0.152
# 50% : 0.176
# 75% : 0.208
# 95% : 0.24399999
# 99% : 0.28
# /tmp/ipykernel_3795083/1836814138.py:3: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print("NaN count:", np.isnan(delay_train).sum())

# %%
import matplotlib.pyplot as plt

valid_delay = delay_train[
    np.isfinite(delay_train)
]

plt.figure(figsize=(8, 5))

plt.hist(
    valid_delay,
    bins=50
)

plt.xlabel("Peak-to-notch delay (seconds)")
plt.ylabel("Number of windows")
plt.title("Distribution of Peak-to-Notch Delay — Training Set")

plt.axvline(
    0.08,
    linestyle="--",
    label="0.08 s"
)

plt.axvline(
    0.35,
    linestyle="--",
    label="0.35 s"
)

plt.legend()

plt.show()
# Out:
# /tmp/ipykernel_3795083/2105359308.py:4: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   np.isfinite(delay_train)
# /tmp/ipykernel_3795083/2105359308.py:3: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at /__w/pytorch/pytorch/aten/src/ATen/native/IndexingUtils.h:37.)
#   valid_delay = delay_train[

# %%
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("delay_train:", delay_train.shape)

print(
    "Number of windows:",
    len(X_train)
)

print(
    "Number of BP labels:",
    len(y_train)
)

print(
    "Number of delays:",
    len(delay_train)
)
# Out:
# X_train: torch.Size([455001, 1, 1000])
# y_train: torch.Size([455001, 2])
# delay_train: torch.Size([455001])
# Number of windows: 455001
# Number of BP labels: 455001
# Number of delays: 455001

# %%
plt.figure(figsize=(7, 5))

plt.scatter(
    valid_delay,
    y_train[np.isfinite(delay_train), 0],
    s=2,
    alpha=0.2
)

plt.xlabel("Peak-to-notch delay (s)")
plt.ylabel("SBP (mmHg)")
plt.title("Delay vs SBP")

plt.show()
# Out:
# /tmp/ipykernel_3795083/3737023816.py:5: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   y_train[np.isfinite(delay_train), 0],
# /tmp/ipykernel_3795083/3737023816.py:5: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at /__w/pytorch/pytorch/aten/src/ATen/native/IndexingUtils.h:37.)
#   y_train[np.isfinite(delay_train), 0],

# %%
plt.figure(figsize=(7, 5))

plt.scatter(
    valid_delay,
    y_train[np.isfinite(delay_train), 1],
    s=2,
    alpha=0.2
)

plt.xlabel("Peak-to-notch delay (s)")
plt.ylabel("DBP (mmHg)")
plt.title("Delay vs DBP")

plt.show()
# Out:
# /tmp/ipykernel_3795083/3149313679.py:5: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   y_train[np.isfinite(delay_train), 1],
# /tmp/ipykernel_3795083/3149313679.py:5: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at /__w/pytorch/pytorch/aten/src/ATen/native/IndexingUtils.h:37.)
#   y_train[np.isfinite(delay_train), 1],

# %% [markdown]
# ## RC Estimation ##

# %%
RC, RC_values = estimate_RC(
    sbp=y_train[:, 0].numpy(),
    dbp=y_train[:, 1].numpy(),
    delay=delay_train
)
# Out:
# Total windows: 455001
# Valid windows: 455001
# Valid percentage: 100.0 %
#
# ================================
# Windkessel RC Estimation
# ================================
# Median RC : 0.2690 s
# Mean RC   : 0.2988 s
# Std RC    : 0.1484 s
# Min RC    : 0.1104 s
# Max RC    : 4.6139 s

# %%
plt.figure(figsize=(8, 5))

plt.hist(
    RC_values,
    bins=100
)

plt.axvline(
    np.median(RC_values),
    linestyle="--",
    label=f"Median = {np.median(RC_values):.3f} s"
)
plt.axvline(
    np.mean(RC_values),
    linestyle="--",
    label=f"Mean = {np.mean(RC_values):.3f} s"
)

plt.xlabel("RC (s)")
plt.xlim(0,1.5)
plt.ylabel("Number of windows")
plt.title("Training-set RC Distribution")
plt.legend()

plt.show()

# %% [markdown]
# It's a highly skewed distribution, so using mean won't be a good idea

# %%
for p in [1, 5, 25, 50, 75, 90, 95, 99, 99.5, 99.9]:
    print(
        f"{p:5.1f}% : "
        f"{np.percentile(RC_values, p):.4f} s"
    )
# Out:
#   1.0% : 0.1461 s
#   5.0% : 0.1693 s
#  25.0% : 0.2193 s
#  50.0% : 0.2690 s
#  75.0% : 0.3345 s
#  90.0% : 0.4155 s
#  95.0% : 0.5153 s
#  99.0% : 0.8889 s
#  99.5% : 1.1005 s
#  99.9% : 1.7278 s

# %%
RC = 0.2994

sbp = y_train[:, 0].cpu().numpy()
dbp = y_train[:, 1].cpu().numpy()
delay = delay_train.cpu().numpy()

dbp_physics = (
    sbp *
    np.exp(-delay / RC)
)

physics_mae = np.mean(
    np.abs(dbp_physics - dbp)
)

physics_rmse = np.sqrt(
    np.mean(
        (dbp_physics - dbp) ** 2
    )
)

print("Physics-only DBP MAE :", physics_mae)
print("Physics-only DBP RMSE:", physics_rmse)
# Out:
# Physics-only DBP MAE : 11.762413
# Physics-only DBP RMSE: 15.052586

# %%
plt.figure(figsize=(7, 6))

plt.scatter(
    dbp,
    dbp_physics,
    s=2,
    alpha=0.2
)

plt.plot(
    [40, 120],
    [40, 120],
    linestyle="--"
)

plt.xlabel("Actual DBP")
plt.ylabel("Windkessel-predicted DBP")
plt.title("Windkessel Physics Check")

plt.show()

# %%
rc_values, mae_values, rmse_values, best_RC_MAE, best_RC_RMSE = grid_search_RC(
    sbp=y_train[:, 0].cpu().numpy(),
    dbp=y_train[:, 1].cpu().numpy(),
    delay=delay_train.cpu().numpy(),
    rc_min=0.10,
    rc_max=1.00,
    rc_step=0.005
)
RC = best_RC_MAE
# Out:
# Valid samples: 455001
#
# ======================================
# RC GRID SEARCH RESULTS
# ======================================
# Best RC by MAE  : 0.2650 s
# Best MAE        : 11.0235 mmHg
#
# Best RC by RMSE : 0.2650 s
# Best RMSE       : 14.0964 mmHg

# %% [markdown]
# ## Establishing Baseline using 1D ResNet ##

# %%
import random
SEED = 42

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


# ============================================================
# Device
# ============================================================

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print("Device:", device)
# Out:
# Device: cuda

# %%
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("X_val:", X_val.shape)
print("y_val:", y_val.shape)

print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: torch.Size([455001, 1, 1000])
# y_train: torch.Size([455001, 2])
# X_val: torch.Size([65488, 1, 1000])
# y_val: torch.Size([65488, 2])
# X_test: torch.Size([133602, 1, 1000])
# y_test: torch.Size([133602, 2])

# %%
from models.PINN import create_data_loaders, create_small_resnet1d
train_loader, val_loader, test_loader = create_data_loaders(
    X_train, y_train,
    X_val, y_val,  
    X_test, y_test)

# %%
model = create_small_resnet1d().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-3
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=2,
    min_lr=1e-6
)

# %%
from models.train import train_model
model, history, train_losses, val_losses = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=50
)
# Out:
# Epoch 1/50 | Train MSE: 10732.96 (SBP RMSE: 95.43, DBP RMSE: 40.32) | Val MSE: 2959.87 (SBP RMSE: 53.17, DBP RMSE: 11.55) | Improved
# Epoch 2/50 | Train MSE: 1074.67 (SBP RMSE: 30.97, DBP RMSE: 10.74) | Val MSE: 421.87 (SBP RMSE: 17.75, DBP RMSE: 10.34) | Improved
# Epoch 3/50 | Train MSE: 401.92 (SBP RMSE: 17.36, DBP RMSE: 10.02) | Val MSE: 400.81 (SBP RMSE: 17.53, DBP RMSE: 9.67) | Improved
# Epoch 4/50 | Train MSE: 349.85 (SBP RMSE: 16.17, DBP RMSE: 9.40) | Val MSE: 416.04 (SBP RMSE: 18.10, DBP RMSE: 9.41) | No improvement (1/10)
# Epoch 5/50 | Train MSE: 314.62 (SBP RMSE: 15.31, DBP RMSE: 8.95) | Val MSE: 423.25 (SBP RMSE: 18.19, DBP RMSE: 9.61) | No improvement (2/10)
# Epoch 6/50 | Train MSE: 288.59 (SBP RMSE: 14.64, DBP RMSE: 8.61) | Val MSE: 365.47 (SBP RMSE: 16.87, DBP RMSE: 8.99) | Improved
# Epoch 7/50 | Train MSE: 267.18 (SBP RMSE: 14.07, DBP RMSE: 8.32) | Val MSE: 379.69 (SBP RMSE: 17.02, DBP RMSE: 9.49) | No improvement (1/10)
# Epoch 8/50 | Train MSE: 251.23 (SBP RMSE: 13.62, DBP RMSE: 8.10) | Val MSE: 342.94 (SBP RMSE: 16.34, DBP RMSE: 8.72) | Improved
# Epoch 9/50 | Train MSE: 237.13 (SBP RMSE: 13.20, DBP RMSE: 7.93) | Val MSE: 334.59 (SBP RMSE: 16.03, DBP RMSE: 8.81) | Improved
# Epoch 10/50 | Train MSE: 226.00 (SBP RMSE: 12.85, DBP RMSE: 7.80) | Val MSE: 348.48 (SBP RMSE: 16.37, DBP RMSE: 8.98) | No improvement (1/10)
# Epoch 11/50 | Train MSE: 215.84 (SBP RMSE: 12.53, DBP RMSE: 7.66) | Val MSE: 347.94 (SBP RMSE: 16.38, DBP RMSE: 8.93) | No improvement (2/10)
# Epoch 12/50 | Train MSE: 207.01 (SBP RMSE: 12.24, DBP RMSE: 7.56) | Val MSE: 342.79 (SBP RMSE: 16.14, DBP RMSE: 9.07) | No improvement (3/10)
# Epoch 13/50 | Train MSE: 199.71 (SBP RMSE: 12.01, DBP RMSE: 7.44) | Val MSE: 331.74 (SBP RMSE: 15.99, DBP RMSE: 8.72) | Improved
# Epoch 14/50 | Train MSE: 192.46 (SBP RMSE: 11.77, DBP RMSE: 7.35) | Val MSE: 348.75 (SBP RMSE: 16.40, DBP RMSE: 8.92) | No improvement (1/10)
# Epoch 15/50 | Train MSE: 185.97 (SBP RMSE: 11.54, DBP RMSE: 7.27) | Val MSE: 327.88 (SBP RMSE: 15.91, DBP RMSE: 8.65) | Improved
# Epoch 16/50 | Train MSE: 180.66 (SBP RMSE: 11.36, DBP RMSE: 7.19) | Val MSE: 312.19 (SBP RMSE: 15.40, DBP RMSE: 8.66) | Improved
# Epoch 17/50 | Train MSE: 175.91 (SBP RMSE: 11.20, DBP RMSE: 7.10) | Val MSE: 330.42 (SBP RMSE: 15.90, DBP RMSE: 8.82) | No improvement (1/10)
# Epoch 18/50 | Train MSE: 171.13 (SBP RMSE: 11.04, DBP RMSE: 7.02) | Val MSE: 321.11 (SBP RMSE: 15.63, DBP RMSE: 8.76) | No improvement (2/10)
# Epoch 19/50 | Train MSE: 167.15 (SBP RMSE: 10.89, DBP RMSE: 6.96) | Val MSE: 329.62 (SBP RMSE: 15.98, DBP RMSE: 8.62) | No improvement (3/10)
# Epoch 20/50 | Train MSE: 162.59 (SBP RMSE: 10.73, DBP RMSE: 6.89) | Val MSE: 334.93 (SBP RMSE: 16.04, DBP RMSE: 8.81) | No improvement (4/10)
# Epoch 21/50 | Train MSE: 159.69 (SBP RMSE: 10.63, DBP RMSE: 6.83) | Val MSE: 344.91 (SBP RMSE: 16.32, DBP RMSE: 8.87) | No improvement (5/10)
# Epoch 22/50 | Train MSE: 156.80 (SBP RMSE: 10.53, DBP RMSE: 6.78) | Val MSE: 331.35 (SBP RMSE: 15.95, DBP RMSE: 8.77) | No improvement (6/10)
# Epoch 23/50 | Train MSE: 153.18 (SBP RMSE: 10.41, DBP RMSE: 6.69) | Val MSE: 330.78 (SBP RMSE: 16.02, DBP RMSE: 8.60) | No improvement (7/10)
# Epoch 24/50 | Train MSE: 150.06 (SBP RMSE: 10.29, DBP RMSE: 6.64) | Val MSE: 324.19 (SBP RMSE: 15.80, DBP RMSE: 8.63) | No improvement (8/10)
# Epoch 25/50 | Train MSE: 147.80 (SBP RMSE: 10.22, DBP RMSE: 6.59) | Val MSE: 339.11 (SBP RMSE: 16.12, DBP RMSE: 8.91) | No improvement (9/10)
# Epoch 26/50 | Train MSE: 145.49 (SBP RMSE: 10.13, DBP RMSE: 6.54) | Val MSE: 320.62 (SBP RMSE: 15.70, DBP RMSE: 8.61) | No improvement (10/10)
#
# Early stopping triggered at epoch 26.
# Best validation loss: 312.1912
#
# Best model loaded successfully.
# Best validation loss: 312.1912

# %%
plt.figure(figsize=(8,5))

plt.plot(train_losses,label="Train")
plt.plot(val_losses,label="Validation")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid()

plt.show()

# %%
from models.train import evaluate_model
predictions, targets, metrics = evaluate_model(
    model,
    test_loader,
    device
)
# Out:
# ================================
# TEST RESULTS
# ================================
# SBP MAE      : 11.24 mmHg
# SBP RMSE     : 16.08 mmHg
# SBP Variance : 258.27 mmHg²
# SBP Std Dev  : 16.07 mmHg
#
# DBP MAE      : 5.91 mmHg
# DBP RMSE     : 8.85 mmHg
# DBP Variance : 77.24 mmHg²
# DBP Std Dev  : 8.79 mmHg

# %% [markdown]
# ## Physics Informed Windkessel ##

# %%
import copy
from models.PINN import create_data_loaders_pinn, plot_mae, train_model_pinn, evaluate_model_pinn

# %%
train_loader, val_loader, test_loader = create_data_loaders_pinn(
    X_train, y_train, delay_train,
    X_val, y_val, delay_val,
    X_test, y_test, delay_test
)

# %%
model = create_small_resnet1d().to(device)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-4
)

# %%
model, best_val_loss = train_model_pinn(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    RC=RC,
    device=device,
    epochs=50,
    lambda_phys=0
# Epoch 11/50 | Train Loss: 107.06 (BP: 106.91, Phys: 143.24) | Train SBP RMSE: 12.46 | Train DBP RMSE: 7.65 | Val Loss: 175.96 (BP: 175.83, Phys: 128.75) | Val SBP RMSE: 16.49 | Val DBP RMSE: 8.93 | No improvement (1/10)
# Epoch 12/50 | Train Loss: 102.87 (BP: 102.73, Phys: 145.32) | Train SBP RMSE: 12.20 | Train DBP RMSE: 7.53 | Val Loss: 190.45 (BP: 190.31, Phys: 146.78) | Val SBP RMSE: 17.24 | Val DBP RMSE: 9.14 | No improvement (2/10)
# Epoch 13/50 | Train Loss: 98.97 (BP: 98.83, Phys: 147.02) | Train SBP RMSE: 11.94 | Train DBP RMSE: 7.43 | Val Loss: 181.09 (BP: 180.95, Phys: 141.80) | Val SBP RMSE: 16.55 | Val DBP RMSE: 9.38 | No improvement (3/10)
# Epoch 14/50 | Train Loss: 95.51 (BP: 95.36, Phys: 148.51) | Train SBP RMSE: 11.71 | Train DBP RMSE: 7.33 | Val Loss: 169.01 (BP: 168.87, Phys: 139.95) | Val SBP RMSE: 16.24 | Val DBP RMSE: 8.61 | Improved
# Epoch 15/50 | Train Loss: 92.71 (BP: 92.56, Phys: 149.82) | Train SBP RMSE: 11.52 | Train DBP RMSE: 7.24 | Val Loss: 172.74 (BP: 172.58, Phys: 151.22) | Val SBP RMSE: 16.37 | Val DBP RMSE: 8.78 | No improvement (1/10)
# Epoch 16/50 | Train Loss: 89.75 (BP: 89.60, Phys: 151.19) | Train SBP RMSE: 11.32 | Train DBP RMSE: 7.15 | Val Loss: 189.83 (BP: 189.70, Phys: 134.26) | Val SBP RMSE: 17.24 | Val DBP RMSE: 9.06 | No improvement (2/10)
# Epoch 17/50 | Train Loss: 87.55 (BP: 87.40, Phys: 152.59) | Train SBP RMSE: 11.16 | Train DBP RMSE: 7.08 | Val Loss: 173.47 (BP: 173.34, Phys: 134.42) | Val SBP RMSE: 16.47 | Val DBP RMSE: 8.69 | No improvement (3/10)
# Epoch 18/50 | Train Loss: 85.17 (BP: 85.02, Phys: 153.70) | Train SBP RMSE: 11.00 | Train DBP RMSE: 7.00 | Val Loss: 169.85 (BP: 169.71, Phys: 142.69) | Val SBP RMSE: 16.16 | Val DBP RMSE: 8.84 | No improvement (4/10)

# %%
results = evaluate_model_pinn(
    model,
    test_loader,
    device
)
# Out:
# ================================
# WINDKESSEL PINN TEST RESULTS
# ================================
# SBP MAE  : 10.95 mmHg
# SBP RMSE : 15.59 mmHg
# DBP MAE  : 5.89 mmHg
# DBP RMSE : 8.81 mmHg

# %%
def plot_mae(results):

    predictions = results["predictions"].numpy()
    targets = results["targets"].numpy()

    # ==========================================
    # Calculate absolute errors
    # ==========================================

    sbp_errors = np.abs(
        predictions[:, 0] - targets[:, 0]
    )

    dbp_errors = np.abs(
        predictions[:, 1] - targets[:, 1]
    )

    # ==========================================
    # MAE and variance
    # ==========================================

    sbp_mae = np.mean(sbp_errors)
    dbp_mae = np.mean(dbp_errors)

    sbp_variance = np.var(sbp_errors)
    dbp_variance = np.var(dbp_errors)

    sbp_std = np.std(sbp_errors)
    dbp_std = np.std(dbp_errors)

    # ==========================================
    # Print statistics
    # ==========================================

    print("\n================================")
    print("ABSOLUTE ERROR STATISTICS")
    print("================================")

    print(f"SBP MAE      : {sbp_mae:.2f} mmHg")
    print(f"SBP Variance : {sbp_variance:.2f} mmHg²")
    print(f"SBP Std Dev  : {sbp_std:.2f} mmHg")

    print()

    print(f"DBP MAE      : {dbp_mae:.2f} mmHg")
    print(f"DBP Variance : {dbp_variance:.2f} mmHg²")
    print(f"DBP Std Dev  : {dbp_std:.2f} mmHg")

    # ==========================================
    # SBP MAE Distribution
    # ==========================================

    plt.figure(figsize=(8, 5))

    plt.hist(
        sbp_errors,
        bins=50,
        alpha=0.7
    )

    plt.axvline(
        sbp_mae,
        linestyle="--",
        linewidth=2,
        label=f"MAE = {sbp_mae:.2f} mmHg"
    )

    plt.xlabel("Absolute Error (mmHg)")
    plt.ylabel("Number of Samples")

    plt.title(
        "SBP Absolute Error Distribution"
    )

    plt.legend()
    plt.grid(
        True,
        alpha=0.3
    )

    plt.show()

    # ==========================================
    # DBP MAE Distribution
    # ==========================================

    plt.figure(figsize=(8, 5))

    plt.hist(
        dbp_errors,
        bins=50,
        alpha=0.7
    )

    plt.axvline(
        dbp_mae,
        linestyle="--",
        linewidth=2,
        label=f"MAE = {dbp_mae:.2f} mmHg"
    )

    plt.xlabel("Absolute Error (mmHg)")
    plt.ylabel("Number of Samples")

    plt.title(
        "DBP Absolute Error Distribution"
    )

    plt.legend()
    plt.grid(
        True,
        alpha=0.3
    )

    plt.show()

# %%
plot_mae(results)
# Out:
# ================================
# ABSOLUTE ERROR STATISTICS
# ================================
# SBP MAE      : 10.95 mmHg
# SBP Variance : 123.04 mmHg²
# SBP Std Dev  : 11.09 mmHg
#
# DBP MAE      : 5.89 mmHg
# DBP Variance : 42.96 mmHg²
# DBP Std Dev  : 6.55 mmHg

# %%
model = create_small_resnet1d().to(device)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-4
)

# %%
model, best_val_loss = train_model_pinn(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    RC=RC,
    device=device,
    epochs=50,
    lambda_phys=0.005,
    patience=10
)
# Out:
# Epoch 1/50 | Train Loss: 5739.96 (BP: 5739.03, Phys: 185.18) | Train SBP RMSE: 98.36 | Train DBP RMSE: 42.47 | Val Loss: 1802.62 (BP: 1800.52, Phys: 421.20) | Val SBP RMSE: 58.53 | Val DBP RMSE: 13.25 | Improved
# Epoch 2/50 | Train Loss: 570.64 (BP: 569.57, Phys: 214.73) | Train SBP RMSE: 31.95 | Train DBP RMSE: 10.89 | Val Loss: 234.38 (BP: 233.99, Phys: 76.73) | Val SBP RMSE: 19.29 | Val DBP RMSE: 9.79 | Improved
# Epoch 3/50 | Train Loss: 201.85 (BP: 201.36, Phys: 98.90) | Train SBP RMSE: 17.37 | Train DBP RMSE: 10.04 | Val Loss: 207.66 (BP: 207.11, Phys: 109.34) | Val SBP RMSE: 17.88 | Val DBP RMSE: 9.73 | Improved
# Epoch 4/50 | Train Loss: 178.72 (BP: 178.17, Phys: 111.21) | Train SBP RMSE: 16.32 | Train DBP RMSE: 9.48 | Val Loss: 204.92 (BP: 204.30, Phys: 123.75) | Val SBP RMSE: 17.84 | Val DBP RMSE: 9.51 | Improved
# Epoch 5/50 | Train Loss: 161.57 (BP: 160.98, Phys: 118.98) | Train SBP RMSE: 15.49 | Train DBP RMSE: 9.05 | Val Loss: 184.83 (BP: 184.20, Phys: 126.20) | Val SBP RMSE: 16.96 | Val DBP RMSE: 8.99 | Improved
mmHg

# %%
plot_mae(results)
# Out:
# ================================
# ABSOLUTE ERROR STATISTICS
# ================================
# SBP MAE      : 11.54 mmHg
# SBP Variance : 124.83 mmHg²
# SBP Std Dev  : 11.17 mmHg
#
# DBP MAE      : 7.29 mmHg
# DBP Variance : 46.20 mmHg²
# DBP Std Dev  : 6.80 mmHg

# %%
model = create_small_resnet1d().to(device)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-4
)

# %%
model, best_val_loss = train_model_pinn(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    RC=RC,
    device=device,
    epochs=50,
    lambda_phys=1,
    patience=10
)
# Out:
# Epoch 1/50 | Train Loss: 5875.23 (BP: 5812.18, Phys: 63.05) | Train SBP RMSE: 97.95 | Train DBP RMSE: 45.05 | Val Loss: 1759.56 (BP: 1676.77, Phys: 82.79) | Val SBP RMSE: 54.01 | Val DBP RMSE: 20.89 | Improved
# Epoch 2/50 | Train Loss: 616.35 (BP: 569.56, Phys: 46.80) | Train SBP RMSE: 30.63 | Train DBP RMSE: 14.17 | Val Loss: 251.17 (BP: 223.60, Phys: 27.57) | Val SBP RMSE: 18.36 | Val DBP RMSE: 10.50 | Improved
# Epoch 3/50 | Train Loss: 238.27 (BP: 217.09, Phys: 21.18) | Train SBP RMSE: 17.58 | Train DBP RMSE: 11.19 | Val Loss: 233.87 (BP: 214.05, Phys: 19.82) | Val SBP RMSE: 17.64 | Val DBP RMSE: 10.81 | Improved
# Epoch 4/50 | Train Loss: 217.85 (BP: 198.35, Phys: 19.50) | Train SBP RMSE: 16.61 | Train DBP RMSE: 10.99 | Val Loss: 263.34 (BP: 243.03, Phys: 20.30) | Val SBP RMSE: 18.78 | Val DBP RMSE: 11.55 | No improvement (1/10)
# Epoch 5/50 | Train Loss: 203.10 (BP: 184.31, Phys: 18.79) | Train SBP RMSE: 15.86 | Train DBP RMSE: 10.82 | Val Loss: 225.07 (BP: 207.66, Phys: 17.41) | Val SBP RMSE: 17.51 | Val DBP RMSE: 10.43 | Improved
# Epoch 6/50 | Train Loss: 191.47 (BP: 172.84, Phys: 18.63) | Train SBP RMSE: 15.22 | Train DBP RMSE: 10.68 | Val Loss: 215.16 (BP: 198.77, Phys: 16.39) | Val SBP RMSE: 17.02 | Val DBP RMSE: 10.38 | Improved
# Epoch 7/50 | Train Loss: 182.20 (BP: 163.63, Phys: 18.58) | Train SBP RMSE: 14.68 | Train DBP RMSE: 10.57 | Val Loss: 206.07 (BP: 190.77, Phys: 15.30) | Val SBP RMSE: 16.50 | Val DBP RMSE: 10.45 | Improved
# Epoch 8/50 | Train Loss: 175.12 (BP: 156.55, Phys: 18.56) | Train SBP RMSE: 14.26 | Train DBP RMSE: 10.48 | Val Loss: 213.74 (BP: 194.07, Phys: 19.67) | Val SBP RMSE: 16.66 | Val DBP RMSE: 10.51 | No improvement (1/10)
# Epoch 9/50 | Train Loss: 168.94 (BP: 150.31, Phys: 18.63) | Train SBP RMSE: 13.87 | Train DBP RMSE: 10.40 | Val Loss: 215.92 (BP: 199.07, Phys: 16.84) | Val SBP RMSE: 17.00 | Val DBP RMSE: 10.44 | No improvement (2/10)
# Epoch 10/50 | Train Loss: 163.69 (BP: 144.99, Phys: 18.70) | Train SBP RMSE: 13.54 | Train DBP RMSE: 10.32 | Val Loss: 208.81 (BP: 191.47, Phys: 17.34) | Val SBP RMSE: 16.59 | Val DBP RMSE: 10.38 | No improvement (3/10)
# Epoch 21/50 | Train Loss: 133.79 (BP: 114.58, Phys: 19.21) | Train SBP RMSE: 11.48 | Train DBP RMSE: 9.87 | Val Loss: 202.90 (BP: 187.70, Phys: 15.19) | Val SBP RMSE: 16.24 | Val DBP RMSE: 10.56 | No improvement (2/10)
# Epoch 22/50 | Train Loss: 132.62 (BP: 113.47, Phys: 19.15) | Train SBP RMSE: 11.39 | Train DBP RMSE: 9.86 | Val Loss: 200.19 (BP: 182.95, Phys: 17.24) | Val SBP RMSE: 16.07 | Val DBP RMSE: 10.37 | No improvement (3/10)
# Epoch 23/50 | Train Loss: 131.03 (BP: 111.88, Phys: 19.16) | Train SBP RMSE: 11.27 | Train DBP RMSE: 9.83 | Val Loss: 205.43 (BP: 187.91, Phys: 17.52) | Val SBP RMSE: 16.50 | Val DBP RMSE: 10.18 | No improvement (4/10)
# Epoch 24/50 | Train Loss: 129.75 (BP: 110.55, Phys: 19.20) | Train SBP RMSE: 11.18 | Train DBP RMSE: 9.80 | Val Loss: 203.41 (BP: 185.53, Phys: 17.89) | Val SBP RMSE: 16.31 | Val DBP RMSE: 10.25 | No improvement (5/10)
# Epoch 25/50 | Train Loss: 128.72 (BP: 109.54, Phys: 19.18) | Train SBP RMSE: 11.11 | Train DBP RMSE: 9.79 | Val Loss: 206.60 (BP: 190.35, Phys: 16.25) | Val SBP RMSE: 16.66 | Val DBP RMSE: 10.15 | No improvement (6/10)
# Epoch 26/50 | Train Loss: 127.63 (BP: 108.44, Phys: 19.18) | Train SBP RMSE: 11.02 | Train DBP RMSE: 9.77 | Val Loss: 198.81 (BP: 181.34, Phys: 17.47) | Val SBP RMSE: 16.01 | Val DBP RMSE: 10.31 | No improvement (7/10)
# Epoch 27/50 | Train Loss: 126.57 (BP: 107.40, Phys: 19.18) | Train SBP RMSE: 10.94 | Train DBP RMSE: 9.75 | Val Loss: 208.32 (BP: 188.38, Phys: 19.93) | Val SBP RMSE: 16.35 | Val DBP RMSE: 10.47 | No improvement (8/10)
# Epoch 28/50 | Train Loss: 125.55 (BP: 106.35, Phys: 19.20) | Train SBP RMSE: 10.86 | Train DBP RMSE: 9.73 | Val Loss: 207.31 (BP: 190.08, Phys: 17.23) | Val SBP RMSE: 16.45 | Val DBP RMSE: 10.47 | No improvement (9/10)
# Epoch 29/50 | Train Loss: 124.54 (BP: 105.34, Phys: 19.21) | Train SBP RMSE: 10.78 | Train DBP RMSE: 9.72 | Val Loss: 205.99 (BP: 187.98, Phys: 18.02) | Val SBP RMSE: 16.30 | Val DBP RMSE: 10.51 | No improvement (10/10)
# Early stopping.

# %%
results = evaluate_model_pinn(
    model,
    test_loader,
    device
)
# Out:
# ================================
# WINDKESSEL PINN TEST RESULTS
# ================================
# SBP MAE  : 11.28 mmHg
# SBP RMSE : 15.89 mmHg
# DBP MAE  : 8.09 mmHg
# DBP RMSE : 10.80 mmHg

# %%
plot_mae(results)
# Out:
# ================================
# ABSOLUTE ERROR STATISTICS
# ================================
# SBP MAE      : 11.28 mmHg
# SBP Variance : 125.28 mmHg²
# SBP Std Dev  : 11.19 mmHg
#
# DBP MAE      : 8.09 mmHg
# DBP Variance : 51.24 mmHg²
# DBP Std Dev  : 7.16 mmHg
