# %% [markdown]
# ## Windkessel-Informed Neural Network for Cuffless BP Estimation
# ==========================================================================
#
# Physics constraint: 2-element Windkessel diastolic decay equation
#  ##   DBP = SBP * exp(-decay_time / RC) ##
#
# This constrains DBP to be consistent with the model's own SBP prediction
# and the measured diastolic decay time (systolic peak -> dicrotic notch).
# SBP remains purely data-driven (see explanation in accompanying chat message).
#
# Sections:
#
#     -  Peak / dicrotic notch detection  (feature extraction from raw PPG)
#
#     -  RC estimation                    (fit once from training data)
#
#     -  Windkessel physics loss          (the actual PINN constraint)
#
#     - Model architecture               (simple 1D CNN)
#
#     - Training loop                    (combines data loss + physics loss)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from scipy.signal import (
    find_peaks,
    savgol_filter
)
import h5py

from tqdm import tqdm
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

from torch.utils.data import Dataset, DataLoader

import sys
sys.path.append("..") 

device = torch.device(
    "cuda" if torch.cuda.is_available()
    else "cpu"
)

print(device)
# Out:
# cuda

# %% [markdown]
# ## Peak / Dicrotic Notch detection ##

# %% [markdown]
# Systolic peak = start of the "pressure is falling" phase, and dicrotic notch = the precise physiological start of diastole, where the heart is no longer pushing anything in.
#
# For this eqn - P(t) = P_sys · exp(-t / RC)
#
# We need t = decay time, which is simply the number of seconds it takes for arterial pressure to go from its systolic peak down to the start of the diastolic (passive) phase, measured as the time gap between the systolic peak and the dicrotic notch on the PPG waveform.

# %%
from models.PINN import get_systolic_peak,calculate_derivatives, get_dicrotic_notch, extract_delay_times, get_delay_time, prepare_UCI_dataset, estimate_RC, grid_search_RC

# %%
FS = 125
WINDOW_SIZE = 1000

MAT_PATH = "/data1/yashvi_bhuva/BP_estimation_using_PPG/UCI/wavelets_data_sym4/Part_1.mat"
f = h5py.File(MAT_PATH, "r")

dataset = f["Part_1"]

# print("Number of recordings:", dataset.shape[0])
ref = dataset[1,0 ]

recording = f[ref][:]

print("Recording shape:", recording.shape)
ppg = recording[:, 0]
abp = recording[:, 1]

print("PPG length:", len(ppg))
print("ABP length:", len(abp))
ppg_std = np.std(ppg)


ppg = (ppg - np.mean(ppg)) / ppg_std # Normalize PPG signal
START = 0

ppg_window = ppg[
    START:START + WINDOW_SIZE
]

print("Window shape:", ppg_window.shape)


# ==========================================
# Detect ALL systolic peaks
# ==========================================

sys_peaks = get_systolic_peak(
    ppg_window,
    FS
)

print(
    "Number of systolic peaks:",
    len(sys_peaks)
)

print(
    "Systolic peak indices:",
    sys_peaks
)


# ==========================================
# Find notch after EACH systolic peak
# ==========================================

notches = []

for sys_idx in sys_peaks:

    notch_idx = get_dicrotic_notch(
        ppg_window,
        sys_idx,
        FS
    )

    notches.append(notch_idx)


# ==========================================
# Print results
# ==========================================

print("\nDetected landmarks:")

for i, (sys_idx, notch_idx) in enumerate(
    zip(sys_peaks, notches)
):

    print(
        f"Beat {i+1}: "
        f"Systolic = {sys_idx} "
        f"({sys_idx / FS:.3f} s), "
        f"Notch = {notch_idx}"
    )


delay_times = []

for sys_idx, notch_idx in zip(
    sys_peaks,
    notches
):

    if notch_idx is None:
        delay_times.append(np.nan)

    else:

        delay = (
            notch_idx - sys_idx
        ) / FS

        delay_times.append(delay)


delay_times = np.array(
    delay_times,
    dtype=np.float32
)


print("\nPeak → notch delays:")

for i, delay in enumerate(delay_times):

    if np.isnan(delay):

        print(
            f"Beat {i+1}: Detection failed"
        )

    else:

        print(
            f"Beat {i+1}: "
            f"{delay:.3f} seconds"
        )
# Out:
# Recording shape: (61000, 3)
# PPG length: 61000
# ABP length: 61000
# Window shape: (1000,)
# Number of systolic peaks: 15
# Systolic peak indices: [ 54 119 184 249 312 377 442 507 569 633 698 761 824 886 950]
#
# Detected landmarks:
# Beat 1: Systolic = 54 (0.432 s), Notch = 74
# Beat 2: Systolic = 119 (0.952 s), Notch = 138
# Beat 3: Systolic = 184 (1.472 s), Notch = 203
# Beat 4: Systolic = 249 (1.992 s), Notch = 267
# Beat 5: Systolic = 312 (2.496 s), Notch = 333
# Beat 6: Systolic = 377 (3.016 s), Notch = 397
# Beat 7: Systolic = 442 (3.536 s), Notch = 461
# Beat 8: Systolic = 507 (4.056 s), Notch = 526
# Beat 9: Systolic = 569 (4.552 s), Notch = 588
# Beat 10: Systolic = 633 (5.064 s), Notch = 652
# Beat 11: Systolic = 698 (5.584 s), Notch = 716
# Beat 12: Systolic = 761 (6.088 s), Notch = 783
# Beat 13: Systolic = 824 (6.592 s), Notch = 844
# Beat 14: Systolic = 886 (7.088 s), Notch = 907
# Beat 15: Systolic = 950 (7.600 s), Notch = 970
#
# Peak → notch delays:
# Beat 1: 0.160 seconds
# Beat 2: 0.152 seconds
# Beat 3: 0.152 seconds
# Beat 4: 0.144 seconds
# Beat 5: 0.168 seconds
# Beat 6: 0.160 seconds
# Beat 7: 0.152 seconds
# Beat 8: 0.152 seconds
# Beat 9: 0.152 seconds
# Beat 10: 0.152 seconds
# Beat 11: 0.144 seconds
# Beat 12: 0.176 seconds
# Beat 13: 0.160 seconds
# Beat 14: 0.168 seconds
# Beat 15: 0.160 seconds

# %%
smooth_ppg = savgol_filter(
    ppg_window,
    window_length=21,
    polyorder=3
)
vpg = np.gradient(smooth_ppg) * FS
apg = np.gradient(vpg) * FS


time = np.arange(
    len(ppg_window)
) / FS

fig, axes = plt.subplots(
    3,
    1,
    figsize=(15, 10),
    sharex=True
)


# ==================================================
# PPG
# ==================================================

axes[0].plot(
    time,
    ppg_window,
    alpha=0.4,
    label="PPG"
)

axes[0].plot(
    time,
    smooth_ppg,
    label="Smoothed PPG"
)


# All systolic peaks

axes[0].scatter(
    sys_peaks / FS,
    smooth_ppg[sys_peaks],
    s=80,
    label="Systolic peaks"
)


# All detected notches

valid_notches = [
    n for n in notches
    if n is not None
]

if len(valid_notches) > 0:

    valid_notches = np.array(
        valid_notches,
        dtype=int
    )

    axes[0].scatter(
        valid_notches / FS,
        smooth_ppg[valid_notches],
        s=100,
        label="Estimated notches"
    )


axes[0].set_ylabel("PPG")
axes[0].legend()
axes[0].grid()


# ==================================================
# VPG
# ==================================================

axes[1].plot(
    time,
    vpg,
    label="VPG"
)

axes[1].set_ylabel("VPG")
axes[1].legend()
axes[1].grid()


# ==================================================
# APG
# ==================================================

axes[2].plot(
    time,
    apg,
    label="APG"
)

axes[2].set_xlabel("Time (seconds)")
axes[2].set_ylabel("APG")
axes[2].legend()
axes[2].grid()


plt.tight_layout()
plt.show()

# %%
delay_time =  get_delay_time(ppg_window)
print(delay_time)
# Out:
# [0.16  0.152 0.152 0.144 0.168 0.16  0.152 0.152 0.152 0.152 0.144 0.176
#  0.16  0.168 0.16 ]

# %%
DATA_PATH = (
    "/data1/yashvi_bhuva/"
    "BP_estimation_using_PPG/UCI/wavelets_data_sym4") 
X_train, y_train, delay_train, X_val, y_val, delay_val, X_test, y_test, delay_test = prepare_UCI_dataset(
    data_path=DATA_PATH)
# Out:
# Total recordings: 12000
# Train recordings: 8400
# Validation recordings: 1200
# Test recordings: 2400
#
# Processing TRAIN recordings...
# Processing recordings: 100%|██████████| 8400/8400 [37:29<00:00,  3.73it/s]
# Skipped recordings: 4
#
# Processing VALIDATION recordings...
# Processing recordings: 100%|██████████| 1200/1200 [05:25<00:00,  3.68it/s]
# Skipped recordings: 0
#
# Processing TEST recordings...
# Processing recordings: 100%|██████████| 2400/2400 [11:06<00:00,  3.60it/s]
# Skipped recordings: 1
#
# ======================================
# DATASET SHAPES
# ======================================
# X_train: torch.Size([455006, 1, 1000])
# y_train: torch.Size([455006, 2])
# delay_train: torch.Size([455006])
# X_val: torch.Size([65486, 1, 1000])
# y_val: torch.Size([65486, 2])
# delay_val: torch.Size([65486])
# X_test: torch.Size([133602, 1, 1000])
# y_test: torch.Size([133602, 2])
# delay_test: torch.Size([133602])

# %%
print("Shape:", delay_train.shape)
print("Dtype:", delay_train.dtype)
print("NaN count:", np.isnan(delay_train).sum())
delay_train_np = delay_train.detach().cpu().numpy().astype(np.float32)
print(
    "NaN percentage:",
    100 * np.isnan(delay_train_np).mean(),
    "%"
)

valid_delay = delay_train_np[
    np.isfinite(delay_train_np)
]

print("Valid values:", len(valid_delay))

if len(valid_delay) > 0:

    print("\nStatistics:")

    print(
        "Min    :",
        np.min(valid_delay)
    )

    print(
        "Max    :",
        np.max(valid_delay)
    )

    print(
        "Mean   :",
        np.mean(valid_delay)
    )

    print(
        "Median :",
        np.median(valid_delay)
    )

    print(
        "Std    :",
        np.std(valid_delay)
    )

if len(valid_delay) > 0:

    print("\nRange checks:")

    print(
        "Below 0.08 s:",
        np.sum(valid_delay < 0.08)
    )

    print(
        "Above 0.35 s:",
        np.sum(valid_delay > 0.35)
    )

    print(
        "Within 0.08–0.35 s:",
        np.sum(
            (valid_delay >= 0.08) &
            (valid_delay <= 0.35)
        )
    )


if len(valid_delay) > 0:

    print("\nPercentiles:")

    for p in [1, 5, 25, 50, 75, 95, 99]:

        print(
            f"{p:2d}% :",
            np.percentile(valid_delay, p)
        )
# Out:
# Shape: torch.Size([455006])
# Dtype: torch.float32
# NaN count: tensor(0)
# NaN percentage: 0.0 %
# Valid values: 455006
#
# Statistics:
# Min    : 0.088
# Max    : 0.336
# Mean   : 0.1808765
# Median : 0.176
# Std    : 0.03675971
#
# Range checks:
# Below 0.08 s: 0
# Above 0.35 s: 0
# Within 0.08–0.35 s: 455006
#
# Percentiles:
#  1% : 0.112
#  5% : 0.128
# 25% : 0.152
# 50% : 0.176
# 75% : 0.208
# 95% : 0.24399999
# 99% : 0.28
# /tmp/ipykernel_2108795/1836814138.py:3: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print("NaN count:", np.isnan(delay_train).sum())

# %%
import matplotlib.pyplot as plt

valid_delay = delay_train[
    np.isfinite(delay_train)
]

plt.figure(figsize=(8, 5))

plt.hist(
    valid_delay,
    bins=50
)

plt.xlabel("Peak-to-notch delay (seconds)")
plt.ylabel("Number of windows")
plt.title("Distribution of Peak-to-Notch Delay — Training Set")

plt.axvline(
    0.08,
    linestyle="--",
    label="0.08 s"
)

plt.axvline(
    0.35,
    linestyle="--",
    label="0.35 s"
)

plt.legend()

plt.show()
# Out:
# /tmp/ipykernel_2108795/2105359308.py:4: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   np.isfinite(delay_train)
# /tmp/ipykernel_2108795/2105359308.py:3: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at /__w/pytorch/pytorch/aten/src/ATen/native/IndexingUtils.h:37.)
#   valid_delay = delay_train[

# %%
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("delay_train:", delay_train.shape)

print(
    "Number of windows:",
    len(X_train)
)

print(
    "Number of BP labels:",
    len(y_train)
)

print(
    "Number of delays:",
    len(delay_train)
)
# Out:
# X_train: torch.Size([455006, 1, 1000])
# y_train: torch.Size([455006, 2])
# delay_train: torch.Size([455006])
# Number of windows: 455006
# Number of BP labels: 455006
# Number of delays: 455006

# %%
plt.figure(figsize=(7, 5))

plt.scatter(
    valid_delay,
    y_train[np.isfinite(delay_train), 0],
    s=2,
    alpha=0.2
)

plt.xlabel("Peak-to-notch delay (s)")
plt.ylabel("SBP (mmHg)")
plt.title("Delay vs SBP")

plt.show()
# Out:
# /tmp/ipykernel_2108795/3737023816.py:5: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   y_train[np.isfinite(delay_train), 0],
# /tmp/ipykernel_2108795/3737023816.py:5: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at /__w/pytorch/pytorch/aten/src/ATen/native/IndexingUtils.h:37.)
#   y_train[np.isfinite(delay_train), 0],

# %%
plt.figure(figsize=(7, 5))

plt.scatter(
    valid_delay,
    y_train[np.isfinite(delay_train), 1],
    s=2,
    alpha=0.2
)

plt.xlabel("Peak-to-notch delay (s)")
plt.ylabel("DBP (mmHg)")
plt.title("Delay vs DBP")

plt.show()
# Out:
# /tmp/ipykernel_2108795/3149313679.py:5: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   y_train[np.isfinite(delay_train), 1],
# /tmp/ipykernel_2108795/3149313679.py:5: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at /__w/pytorch/pytorch/aten/src/ATen/native/IndexingUtils.h:37.)
#   y_train[np.isfinite(delay_train), 1],

# %% [markdown]
# ## RC Estimation ##

# %%
RC, RC_values = estimate_RC(
    sbp=y_train[:, 0].numpy(),
    dbp=y_train[:, 1].numpy(),
    delay=delay_train
)
# Out:
# Total windows: 455006
# Valid windows: 455006
# Valid percentage: 100.0 %
#
# ================================
# Windkessel RC Estimation
# ================================
# Median RC : 0.2690 s
# Mean RC   : 0.2988 s
# Std RC    : 0.1483 s
# Min RC    : 0.1104 s
# Max RC    : 4.6139 s

# %%
plt.figure(figsize=(8, 5))

plt.hist(
    RC_values,
    bins=100
)

plt.axvline(
    np.median(RC_values),
    linestyle="--",
    label=f"Median = {np.median(RC_values):.3f} s"
)
plt.axvline(
    np.mean(RC_values),
    linestyle="--",
    label=f"Mean = {np.mean(RC_values):.3f} s"
)

plt.xlabel("RC (s)")
plt.xlim(0,1.5)
plt.ylabel("Number of windows")
plt.title("Training-set RC Distribution")
plt.legend()

plt.show()

# %% [markdown]
# It's a highly skewed distribution, so using mean won't be a good idea

# %%
for p in [1, 5, 25, 50, 75, 90, 95, 99, 99.5, 99.9]:
    print(
        f"{p:5.1f}% : "
        f"{np.percentile(RC_values, p):.4f} s"
    )
# Out:
#   1.0% : 0.1461 s
#   5.0% : 0.1694 s
#  25.0% : 0.2194 s
#  50.0% : 0.2690 s
#  75.0% : 0.3345 s
#  90.0% : 0.4156 s
#  95.0% : 0.5148 s
#  99.0% : 0.8887 s
#  99.5% : 1.1005 s
#  99.9% : 1.7278 s

# %%
RC = 0.2994

sbp = y_train[:, 0].cpu().numpy()
dbp = y_train[:, 1].cpu().numpy()
delay = delay_train.cpu().numpy()

dbp_physics = (
    sbp *
    np.exp(-delay / RC)
)

physics_mae = np.mean(
    np.abs(dbp_physics - dbp)
)

physics_rmse = np.sqrt(
    np.mean(
        (dbp_physics - dbp) ** 2
    )
)

print("Physics-only DBP MAE :", physics_mae)
print("Physics-only DBP RMSE:", physics_rmse)
# Out:
# Physics-only DBP MAE : 11.754369
# Physics-only DBP RMSE: 15.04199

# %%
plt.figure(figsize=(7, 6))

plt.scatter(
    dbp,
    dbp_physics,
    s=2,
    alpha=0.2
)

plt.plot(
    [40, 120],
    [40, 120],
    linestyle="--"
)

plt.xlabel("Actual DBP")
plt.ylabel("Windkessel-predicted DBP")
plt.title("Windkessel Physics Check")

plt.show()

# %%
rc_values, mae_values, rmse_values, best_RC_MAE, best_RC_RMSE = grid_search_RC(
    sbp=y_train[:, 0].cpu().numpy(),
    dbp=y_train[:, 1].cpu().numpy(),
    delay=delay_train.cpu().numpy(),
    rc_min=0.10,
    rc_max=1.00,
    rc_step=0.005
)
RC = best_RC_MAE
# Out:
# Valid samples: 455006
#
# ======================================
# RC GRID SEARCH RESULTS
# ======================================
# Best RC by MAE  : 0.2650 s
# Best MAE        : 11.0148 mmHg
#
# Best RC by RMSE : 0.2650 s
# Best RMSE       : 14.0858 mmHg

# %% [markdown]
# ## Establishing Baseline using 1D ResNet ##

# %%
import random
SEED = 42

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


# ============================================================
# Device
# ============================================================

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print("Device:", device)
# Out:
# Device: cuda

# %%
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("X_val:", X_val.shape)
print("y_val:", y_val.shape)

print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: torch.Size([455006, 1, 1000])
# y_train: torch.Size([455006, 2])
# X_val: torch.Size([65486, 1, 1000])
# y_val: torch.Size([65486, 2])
# X_test: torch.Size([133602, 1, 1000])
# y_test: torch.Size([133602, 2])

# %%
from models.PINN import create_data_loaders, create_small_resnet1d
train_loader, val_loader, test_loader = create_data_loaders(
    X_train, y_train,
    X_val, y_val,  
    X_test, y_test)

# %%
model = create_small_resnet1d().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-3
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=2,
    min_lr=1e-6
)

# %%
from models.train import train_model
model, history, train_losses, val_losses = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=50
)
# Out:
# Epoch 1/50 | Train MSE: 10739.01 (SBP RMSE: 95.46, DBP RMSE: 40.32) | Val MSE: 3222.98 (SBP RMSE: 55.45, DBP RMSE: 12.17) | Improved
# Epoch 2/50 | Train MSE: 1055.09 (SBP RMSE: 30.67, DBP RMSE: 10.71) | Val MSE: 466.15 (SBP RMSE: 19.15, DBP RMSE: 9.98) | Improved
# Epoch 3/50 | Train MSE: 396.78 (SBP RMSE: 17.18, DBP RMSE: 10.08) | Val MSE: 510.17 (SBP RMSE: 20.25, DBP RMSE: 10.01) | No improvement (1/10)
# Epoch 4/50 | Train MSE: 349.68 (SBP RMSE: 16.16, DBP RMSE: 9.42) | Val MSE: 382.72 (SBP RMSE: 17.22, DBP RMSE: 9.29) | Improved
# Epoch 5/50 | Train MSE: 316.30 (SBP RMSE: 15.36, DBP RMSE: 8.96) | Val MSE: 428.12 (SBP RMSE: 18.44, DBP RMSE: 9.39) | No improvement (1/10)
# Epoch 6/50 | Train MSE: 289.96 (SBP RMSE: 14.69, DBP RMSE: 8.61) | Val MSE: 351.04 (SBP RMSE: 16.49, DBP RMSE: 8.90) | Improved
# Epoch 7/50 | Train MSE: 270.13 (SBP RMSE: 14.16, DBP RMSE: 8.34) | Val MSE: 359.38 (SBP RMSE: 16.77, DBP RMSE: 8.83) | No improvement (1/10)
# Epoch 8/50 | Train MSE: 252.66 (SBP RMSE: 13.66, DBP RMSE: 8.13) | Val MSE: 375.42 (SBP RMSE: 17.08, DBP RMSE: 9.15) | No improvement (2/10)
# Epoch 9/50 | Train MSE: 239.10 (SBP RMSE: 13.25, DBP RMSE: 7.97) | Val MSE: 348.12 (SBP RMSE: 16.44, DBP RMSE: 8.82) | Improved
# Epoch 10/50 | Train MSE: 226.72 (SBP RMSE: 12.87, DBP RMSE: 7.82) | Val MSE: 336.58 (SBP RMSE: 16.13, DBP RMSE: 8.73) | Improved
# Epoch 11/50 | Train MSE: 217.60 (SBP RMSE: 12.58, DBP RMSE: 7.70) | Val MSE: 335.22 (SBP RMSE: 16.04, DBP RMSE: 8.84) | Improved
# Epoch 12/50 | Train MSE: 208.65 (SBP RMSE: 12.29, DBP RMSE: 7.60) | Val MSE: 344.58 (SBP RMSE: 16.28, DBP RMSE: 8.91) | No improvement (1/10)
# Epoch 13/50 | Train MSE: 200.74 (SBP RMSE: 12.03, DBP RMSE: 7.48) | Val MSE: 363.84 (SBP RMSE: 16.92, DBP RMSE: 8.80) | No improvement (2/10)
# Epoch 14/50 | Train MSE: 193.95 (SBP RMSE: 11.79, DBP RMSE: 7.41) | Val MSE: 325.79 (SBP RMSE: 15.87, DBP RMSE: 8.59) | Improved
# Epoch 15/50 | Train MSE: 187.69 (SBP RMSE: 11.59, DBP RMSE: 7.31) | Val MSE: 330.05 (SBP RMSE: 15.82, DBP RMSE: 8.94) | No improvement (1/10)
# Epoch 16/50 | Train MSE: 182.73 (SBP RMSE: 11.41, DBP RMSE: 7.25) | Val MSE: 348.35 (SBP RMSE: 16.34, DBP RMSE: 9.01) | No improvement (2/10)
# Epoch 17/50 | Train MSE: 177.38 (SBP RMSE: 11.23, DBP RMSE: 7.17) | Val MSE: 337.64 (SBP RMSE: 16.14, DBP RMSE: 8.78) | No improvement (3/10)
# Epoch 18/50 | Train MSE: 173.40 (SBP RMSE: 11.09, DBP RMSE: 7.09) | Val MSE: 334.11 (SBP RMSE: 16.03, DBP RMSE: 8.79) | No improvement (4/10)
# Epoch 19/50 | Train MSE: 168.53 (SBP RMSE: 10.92, DBP RMSE: 7.01) | Val MSE: 352.88 (SBP RMSE: 16.53, DBP RMSE: 8.92) | No improvement (5/10)
# Epoch 20/50 | Train MSE: 164.89 (SBP RMSE: 10.80, DBP RMSE: 6.94) | Val MSE: 342.79 (SBP RMSE: 16.31, DBP RMSE: 8.77) | No improvement (6/10)
# Epoch 21/50 | Train MSE: 161.68 (SBP RMSE: 10.68, DBP RMSE: 6.90) | Val MSE: 333.58 (SBP RMSE: 16.01, DBP RMSE: 8.80) | No improvement (7/10)
# Epoch 22/50 | Train MSE: 159.17 (SBP RMSE: 10.60, DBP RMSE: 6.85) | Val MSE: 342.37 (SBP RMSE: 16.13, DBP RMSE: 9.07) | No improvement (8/10)
# Epoch 23/50 | Train MSE: 155.29 (SBP RMSE: 10.46, DBP RMSE: 6.77) | Val MSE: 332.37 (SBP RMSE: 15.99, DBP RMSE: 8.76) | No improvement (9/10)
# Epoch 24/50 | Train MSE: 152.28 (SBP RMSE: 10.35, DBP RMSE: 6.72) | Val MSE: 333.25 (SBP RMSE: 16.00, DBP RMSE: 8.79) | No improvement (10/10)
#
# Early stopping triggered at epoch 24.
# Best validation loss: 325.7897
#
# Best model loaded successfully.
# Best validation loss: 325.7897

# %%
plt.figure(figsize=(8,5))

plt.plot(train_losses,label="Train")
plt.plot(val_losses,label="Validation")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid()

plt.show()

# %%
from models.train import evaluate_model
predictions, targets, metrics = evaluate_model(
    model,
    test_loader,
    device
)
# Out:
# ================================
# WINDKESSEL PINN TEST RESULTS
# ================================
# SBP MAE  : 11.45 mmHg
# SBP RMSE : 16.30 mmHg
# DBP MAE  : 6.03 mmHg
# DBP RMSE : 9.08 mmHg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 from models.train import evaluate_model
# ----> 2 predictions, targets, metrics = evaluate_model(
#       3     model,
#       4     test_loader,
#       5     device
#       6 )
#
# ValueError: too many values to unpack (expected 3)

# %% [markdown]
# ## Physics Informed Windkessel ##

# %%
import copy
from models.PINN import create_data_loaders_pinn, plot_mae, train_model_pinn, evaluate_model_pinn

# %%
train_loader, val_loader, test_loader = create_data_loaders_pinn(
    X_train, y_train, delay_train,
    X_val, y_val, delay_val,
    X_test, y_test, delay_test
)

# %%
model = create_small_resnet1d().to(device)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-4
)

# %%
model, best_val_loss = train_model_pinn(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    RC=RC,
    device=device,
    epochs=50,
    lambda_phys=0.001,
    patience=10
)
# Out:
# Epoch 1/50 | Train Loss: 
| No improvement (10/10)
# Early stopping.

# %%
results = evaluate_model_pinn(
    model,
    test_loader,
    device
)
# Out:
# ================================
# WINDKESSEL PINN TEST RESULTS
# ================================
# SBP MAE  : 10.93 mmHg
# SBP RMSE : 15.76 mmHg
# DBP MAE  : 5.86 mmHg
# DBP RMSE : 8.77 mmHg

# %%
def plot_mae(results):

    predictions = results["predictions"].numpy()
    targets = results["targets"].numpy()

    # ==========================================
    # Calculate absolute errors
    # ==========================================

    sbp_errors = np.abs(
        predictions[:, 0] - targets[:, 0]
    )

    dbp_errors = np.abs(
        predictions[:, 1] - targets[:, 1]
    )

    # ==========================================
    # MAE and variance
    # ==========================================

    sbp_mae = np.mean(sbp_errors)
    dbp_mae = np.mean(dbp_errors)

    sbp_variance = np.var(sbp_errors)
    dbp_variance = np.var(dbp_errors)

    sbp_std = np.std(sbp_errors)
    dbp_std = np.std(dbp_errors)

    # ==========================================
    # Print statistics
    # ==========================================

    print("\n================================")
    print("ABSOLUTE ERROR STATISTICS")
    print("================================")

    print(f"SBP MAE      : {sbp_mae:.2f} mmHg")
    print(f"SBP Variance : {sbp_variance:.2f} mmHg²")
    print(f"SBP Std Dev  : {sbp_std:.2f} mmHg")

    print()

    print(f"DBP MAE      : {dbp_mae:.2f} mmHg")
    print(f"DBP Variance : {dbp_variance:.2f} mmHg²")
    print(f"DBP Std Dev  : {dbp_std:.2f} mmHg")

    # ==========================================
    # SBP MAE Distribution
    # ==========================================

    plt.figure(figsize=(8, 5))

    plt.hist(
        sbp_errors,
        bins=50,
        alpha=0.7
    )

    plt.axvline(
        sbp_mae,
        linestyle="--",
        linewidth=2,
        label=f"MAE = {sbp_mae:.2f} mmHg"
    )

    plt.xlabel("Absolute Error (mmHg)")
    plt.ylabel("Number of Samples")

    plt.title(
        "SBP Absolute Error Distribution"
    )

    plt.legend()
    plt.grid(
        True,
        alpha=0.3
    )

    plt.show()

    # ==========================================
    # DBP MAE Distribution
    # ==========================================

    plt.figure(figsize=(8, 5))

    plt.hist(
        dbp_errors,
        bins=50,
        alpha=0.7
    )

    plt.axvline(
        dbp_mae,
        linestyle="--",
        linewidth=2,
        label=f"MAE = {dbp_mae:.2f} mmHg"
    )

    plt.xlabel("Absolute Error (mmHg)")
    plt.ylabel("Number of Samples")

    plt.title(
        "DBP Absolute Error Distribution"
    )

    plt.legend()
    plt.grid(
        True,
        alpha=0.3
    )

    plt.show()

# %%
plot_mae(results)
# Out:
# ================================
# ABSOLUTE ERROR STATISTICS
# ================================
# SBP MAE      : 10.93 mmHg
# SBP Variance : 128.89 mmHg²
# SBP Std Dev  : 11.35 mmHg
#
# DBP MAE      : 5.86 mmHg
# DBP Variance : 42.63 mmHg²
# DBP Std Dev  : 6.53 mmHg

# %%
model = create_small_resnet1d().to(device)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-4
)

# %%
model, best_val_loss = train_model_pinn(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    RC=RC,
    device=device,
    epochs=50,
    lambda_phys=0.005,
    patience=10
)
# Out:
# Epoch 1/50 | Train Loss: 5559.38 (BP: 5558.47, Phys: 182.42) | Train SBP RMSE: 96.64 | Train DBP RMSE: 42.17 | Val Loss: 1285.42 (BP: 1283.19, Phys: 445.41) | Val SBP RMSE: 49.55 | Val DBP RMSE: 10.56 | Improved
# Epoch 2/50 | Train Loss: 469.26 (BP: 468.35, Phys: 182.48) | Train SBP RMSE: 28.67 | Train DBP RMSE: 10.72 | Val Loss: 214.34 (BP: 213.91, Phys: 84.86) | Val SBP RMSE: 18.14 | Val DBP RMSE: 9.94 | Improved
# Epoch 24/50 | Train Loss: 75.73 (BP: 74.95, Phys: 155.95) | Train SBP RMSE: 10.26 | Train DBP RMSE: 6.68 | Val Loss: 172.67 (BP: 171.88, Phys: 157.70) | Val SBP RMSE: 16.33 | Val DBP RMSE: 8.78 | No improvement (9/10)
# Epoch 25/50 | Train Loss: 74.42 (BP: 73.64, Phys: 156.98) | Train SBP RMSE: 10.18 | Train DBP RMSE: 6.61 | Val Loss: 176.00 (BP: 175.19, Phys: 162.34) | Val SBP RMSE: 16.28 | Val DBP RMSE: 9.24 | No improvement (10/10)
# Early stopping.

# %%
results = evaluate_model_pinn(
    model,
    test_loader,
    device
)
# Out:
# ================================
# WINDKESSEL PINN TEST RESULTS
# ================================
# SBP MAE  : 11.12 mmHg
# SBP RMSE : 15.88 mmHg
# DBP MAE  : 5.86 mmHg
# DBP RMSE : 8.76 mmHg

# %%
plot_mae(results)
# Out:
# ================================
# ABSOLUTE ERROR STATISTICS
# ================================
# SBP MAE      : 11.12 mmHg
# SBP Variance : 128.46 mmHg²
# SBP Std Dev  : 11.33 mmHg
#
# DBP MAE      : 5.86 mmHg
# DBP Variance : 42.34 mmHg²
# DBP Std Dev  : 6.51 mmHg

# %%
model = create_small_resnet1d().to(device)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-4
)

# %%
model, best_val_loss = train_model_pinn(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    RC=RC,
    device=device,
    epochs=50,
    lambda_phys=0.01,
    patience=10
)
# Out:
# Epoch 1/50 | Train Loss: 5717.18 (BP: 5714.83, Phys: 234.83) | Train SBP RMSE: 98.67 | Train DBP RMSE: 41.15 | Val Loss: 1706.13 (BP: 1701.52, Phys: 461.42) | Val SBP RMSE: 57.06 | Val DBP RMSE: 12.11 | Improved
# Epoch 2/50 | Train Loss: 521.42 (BP: 519.34, Phys: 207.77) | Train SBP RMSE: 30.40 | Train DBP RMSE: 10.70 | Val Loss: 236.25 (BP: 235.48, Phys: 77.62) | Val SBP RMSE: 19.31 | Val DBP RMSE: 9.90 | Improved
# Epoch 3/50 | Train Loss: 203.21 (BP: 202.25, Phys: 96.62) | Train SBP RMSE: 17.40 | Train DBP RMSE: 10.09 | Val Loss: 194.81 (BP: 193.89, Phys: 91.68) | Val SBP RMSE: 17.36 | Val DBP RMSE: 9.29 | Improved
# Epoch 4/50 | Train Loss: 179.11 (BP: 178.01, Phys: 109.43) | Train SBP RMSE: 16.34 | Train DBP RMSE: 9.43 | Val Loss: 199.59 (BP: 198.55, Phys: 103.62) | Val SBP RMSE: 17.68 | Val DBP RMSE: 9.19 | No improvement (1/10)
# Epoch 5/50 | Train Loss: 161.88 (BP: 160.70, Phys: 117.26) | Train SBP RMSE: 15.50 | Train DBP RMSE: 9.01 | Val Loss: 192.45 (BP: 191.34, Phys: 111.14) | Val SBP RMSE: 17.18 | Val DBP RMSE: 9.36 | Improved
# Epoch 6/50 | Train Loss: 148.55 (BP: 147.32, Phys: 122.45) | Train SBP RMSE: 14.81 | Train DBP RMSE: 8.68 | Val Loss: 194.10 (BP: 192.99, Phys: 111.31) | Val SBP RMSE: 17.42 | Val DBP RMSE: 9.08 | No improvement (1/10)
# Epoch 7/50 | Train Loss: 137.68 (BP: 136.42, Phys: 126.44) | Train SBP RMSE: 14.21 | Train DBP RMSE: 8.42 | Val Loss: 179.64 (BP: 178.43, Phys: 121.19) | Val SBP RMSE: 16.76 | Val DBP RMSE: 8.72 | Improved
# Epoch 8/50 | Train Loss: 129.72 (BP: 128.42, Phys: 129.58) | Train SBP RMSE: 13.77 | Train DBP RMSE: 8.20 | Val Loss: 177.36 (BP: 176.17, Phys: 118.46) | Val SBP RMSE: 16.42 | Val DBP RMSE: 9.09 | Improved
# Epoch 28/50 | Train Loss: 78.70 (BP: 72.26, Phys: 128.91) | Train SBP RMSE: 10.03 | Train DBP RMSE: 6.63 | Val Loss: 177.02 (BP: 170.95, Phys: 121.49) | Val SBP RMSE: 16.33 | Val DBP RMSE: 8.66 | No improvement (9/10)
# Epoch 29/50 | Train Loss: 77.53 (BP: 71.05, Phys: 129.63) | Train SBP RMSE: 9.95 | Train DBP RMSE: 6.57 | Val Loss: 171.15 (BP: 165.08, Phys: 121.58) | Val SBP RMSE: 15.97 | Val DBP RMSE: 8.66 | No improvement (10/10)
# Early stopping.

# %%
results = evaluate_model_pinn(
    model,
    test_loader,
    device
)
# Out:
# ================================
# WINDKESSEL PINN TEST RESULTS
# ================================
# SBP MAE  : 11.16 mmHg
# SBP RMSE : 15.94 mmHg
# DBP MAE  : 5.91 mmHg
# DBP RMSE : 8.84 mmHg

# %%
plot_mae(results)
# Out:
# ================================
# ABSOLUTE ERROR STATISTICS
# ================================
# SBP MAE      : 11.16 mmHg
# SBP Variance : 129.38 mmHg²
# SBP Std Dev  : 11.37 mmHg
#
# DBP MAE      : 5.91 mmHg
# DBP Variance : 43.21 mmHg²
# DBP Std Dev  : 6.57 mmHg

# %%
model = create_small_resnet1d().to(device)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-4
)

# %%
model, best_val_loss = train_model_pinn(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    RC=RC,
    device=device,
    epochs=50,
    lambda_phys=0.1,
    patience=10
)
# Out:
# Epoch 1/50 | Train Loss: 5602.01 (BP: 5586.00, Phys: 160.09) | Train SBP RMSE: 96.89 | Train DBP RMSE: 42.25 | Val Loss: 1668.70 (BP: 1635.68, Phys: 330.24) | Val SBP RMSE: 55.61 | Val DBP RMSE: 13.38 | Improved
# Epoch 2/50 | Train Loss: 559.81 (BP: 543.79, Phys: 160.20) | Train SBP RMSE: 31.04 | Train DBP RMSE: 11.15 | Val Loss: 335.33 (BP: 325.75, Phys: 95.78) | Val SBP RMSE: 22.38 | Val DBP RMSE: 12.27 | Improved
# Epoch 3/50 | Train Loss: 211.28 (BP: 203.67, Phys: 76.13) | Train SBP RMSE: 17.47 | Train DBP RMSE: 10.11 | Val Loss: 221.79 (BP: 215.50, Phys: 62.92) | Val SBP RMSE: 18.39 | Val DBP RMSE: 9.63 | Improved
# Epoch 4/50 | Train Loss: 187.26 (BP: 179.35, Phys: 79.03) | Train SBP RMSE: 16.36 | Train DBP RMSE: 9.55 | Val Loss: 207.16 (BP: 199.37, Phys: 77.82) | Val SBP RMSE: 17.67 | Val DBP RMSE: 9.30 | Improved
# Epoch 5/50 | Train Loss: 170.25 (BP: 161.95, Phys: 83.07) | Train SBP RMSE: 15.49 | Train DBP RMSE: 9.16 | Val Loss: 195.89 (BP: 187.94, Phys: 79.53) | Val SBP RMSE: 17.02 | Val DBP RMSE: 9.28 | Improved
# Epoch 6/50 | Train Loss: 156.98 (BP: 148.32, Phys: 86.58) | Train SBP RMSE: 14.79 | Train DBP RMSE: 8.82 | Val Loss: 196.32 (BP: 187.57, Phys: 87.46) | Val SBP RMSE: 16.98 | Val DBP RMSE: 9.31 | No improvement (1/10)
# Epoch 7/50 | Train Loss: 145.86 (BP: 136.94, Phys: 89.26) | Train SBP RMSE: 14.16 | Train DBP RMSE: 8.56 | Val Loss: 193.33 (BP: 184.09, Phys: 92.36) | Val SBP RMSE: 16.62 | Val DBP RMSE: 9.60 | Improved
# Epoch 8/50 | Train Loss: 137.66 (BP: 128.53, Phys: 91.29) | Train SBP RMSE: 13.68 | Train DBP RMSE: 8.36 | Val Loss: 200.39 (BP: 190.72, Phys: 96.72) | Val SBP RMSE: 17.15 | Val DBP RMSE: 9.35 | No improvement (1/10)
# Epoch 9/50 | Train Loss: 130.51 (BP: 121.19, Phys: 93.12) | Train SBP RMSE: 13.24 | Train DBP RMSE: 8.20 | Val Loss: 188.49 (BP: 178.62, Phys: 98.69) | Val SBP RMSE: 16.63 | Val DBP RMSE: 8.98 | Improved
# Epoch 10/50 | Train Loss: 124.77 (BP: 115.32, Phys: 94.51) | Train SBP RMSE: 12.88 | Train DBP RMSE: 8.05 | Val Loss: 183.46 (BP: 173.45, Phys: 100.17) | Val SBP RMSE: 16.34 | Val DBP RMSE: 8.94 | Improved
# Epoch 11/50 | Train Loss: 119.87 (BP: 110.31, Phys: 95.62) | Train SBP RMSE: 12.56 | Train DBP RMSE: 7.93 | Val Loss: 197.79 (BP: 187.86, Phys: 99.30) | Val SBP RMSE: 17.07 | Val DBP RMSE: 9.18 | No improvement (1/10)
# Epoch 12/50 | Train Loss: 115.66 (BP: 106.00, Phys: 96.57) | Train SBP RMSE: 12.28 | Train DBP RMSE: 7.83 | Val Loss: 184.84 (BP: 174.89, Phys: 99.49) | Val SBP RMSE: 16.43 | Val DBP RMSE: 8.94 | No improvement (2/10)
# Epoch 13/50 | Train Loss: 111.94 (BP: 102.20, Phys: 97.38) | Train SBP RMSE: 12.03 | Train DBP RMSE: 7.73 | Val Loss: 191.93 (BP: 180.46, Phys: 114.65) | Val SBP RMSE: 16.71 | Val DBP RMSE: 9.04 | No improvement (3/10)
# Epoch 14/50 | Train Loss: 108.86 (BP: 99.04, Phys: 98.20) | Train SBP RMSE: 11.80 | Train DBP RMSE: 7.66 | Val Loss: 191.12 (BP: 181.58, Phys: 95.46) | Val SBP RMSE: 16.84 | Val DBP RMSE: 8.91 | No improvement (4/10)
# Epoch 15/50 | Train Loss: 105.51 (BP: 95.58, Phys: 99.34) | Train SBP RMSE: 11.57 | Train DBP RMSE: 7.57 | Val Loss: 170.22 (BP: 161.01, Phys: 92.14) | Val SBP RMSE: 15.69 | Val DBP RMSE: 8.72 | Improved
# Epoch 16/50 | Train Loss: 102.74 (BP: 92.77, Phys: 99.67) | Train SBP RMSE: 11.38 | Train DBP RMSE: 7.49 | Val Loss: 178.91 (BP: 168.91, Phys: 100.03) | Val SBP RMSE: 16.00 | Val DBP RMSE: 9.05 | No improvement (1/10)
# Epoch 17/50 | Train Loss: 100.69 (BP: 90.62, Phys: 100.66) | Train SBP RMSE: 11.23 | Train DBP RMSE: 7.42 | Val Loss: 177.05 (BP: 167.36, Phys: 96.85) | Val SBP RMSE: 16.03 | Val DBP RMSE: 8.82 | No improvement (2/10)
# Epoch 18/50 | Train Loss: 98.33 (BP: 88.20, Phys: 101.22) | Train SBP RMSE: 11.07 | Train DBP RMSE: 7.34 | Val Loss: 190.24 (BP: 179.58, Phys: 106.60) | Val SBP RMSE: 16.71 | Val DBP RMSE: 8.93 | No improvement (3/10)
# Epoch 19/50 | Train Loss: 96.17 (BP: 86.00, Phys: 101.78) | Train SBP RMSE: 10.90 | Train DBP RMSE: 7.30 | Val Loss: 192.34 (BP: 182.13, Phys: 102.03) | Val SBP RMSE: 16.93 | Val DBP RMSE: 8.82 | No improvement (4/10)
# Epoch 20/50 | Train Loss: 94.51 (BP: 84.28, Phys: 102.34) | Train SBP RMSE: 10.78 | Train DBP RMSE: 7.23 | Val Loss: 184.82 (BP: 174.22, Phys: 106.03) | Val SBP RMSE: 16.47 | Val DBP RMSE: 8.78 | No improvement (5/10)
# Epoch 21/50 | Train Loss: 93.04 (BP: 82.77, Phys: 102.68) | Train SBP RMSE: 10.68 | Train DBP RMSE: 7.18 | Val Loss: 184.29 (BP: 174.59, Phys: 97.02) | Val SBP RMSE: 16.51 | Val DBP RMSE: 8.75 | No improvement (6/10)
# Epoch 22/50 | Train Loss: 90.85 (BP: 80.50, Phys: 103.48) | Train SBP RMSE: 10.51 | Train DBP RMSE: 7.10 | Val Loss: 172.56 (BP: 163.00, Phys: 95.57) | Val SBP RMSE: 15.86 | Val DBP RMSE: 8.64 | No improvement (7/10)
# Epoch 23/50 | Train Loss: 89.65 (BP: 79.24, Phys: 104.16) | Train SBP RMSE: 10.43 | Train DBP RMSE: 7.05 | Val Loss: 172.63 (BP: 162.91, Phys: 97.16) | Val SBP RMSE: 15.85 | Val DBP RMSE: 8.63 | No improvement (8/10)
# Epoch 24/50 | Train Loss: 88.34 (BP: 77.88, Phys: 104.57) | Train SBP RMSE: 10.32 | Train DBP RMSE: 7.01 | Val Loss: 171.67 (BP: 162.29, Phys: 93.82) | Val SBP RMSE: 15.78 | Val DBP RMSE: 8.69 | No improvement (9/10)
# Epoch 25/50 | Train Loss: 87.06 (BP: 76.55, Phys: 105.11) | Train SBP RMSE: 10.24 | Train DBP RMSE: 6.95 | Val Loss: 181.40 (BP: 172.09, Phys: 93.05) | Val SBP RMSE: 16.38 | Val DBP RMSE: 8.71 | No improvement (10/10)
# Early stopping.

# %%
results = evaluate_model_pinn(
    model,
    test_loader,
    device
)
# Out:
# ================================
# WINDKESSEL PINN TEST RESULTS
# ================================
# SBP MAE  : 11.13 mmHg
# SBP RMSE : 15.91 mmHg
# DBP MAE  : 6.00 mmHg
# DBP RMSE : 8.96 mmHg

# %%
plot_mae(results)
# Out:
# ================================
# ABSOLUTE ERROR STATISTICS
# ================================
# SBP MAE      : 11.13 mmHg
# SBP Variance : 129.09 mmHg²
# SBP Std Dev  : 11.36 mmHg
#
# DBP MAE      : 6.00 mmHg
# DBP Variance : 44.30 mmHg²
# DBP Std Dev  : 6.66 mmHg

# %%
model = create_small_resnet1d().to(device)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-4
)

# %%
model, best_val_loss = train_model_pinn(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    RC=RC,
    device=device,
    epochs=50,
    lambda_phys=0.5,
    patience=10
)
# Out:
# Epoch 1/50 | Train Loss: 5753.25 (BP: 5703.15, Phys: 100.21) | Train SBP RMSE: 97.38 | Train DBP RMSE: 43.86 | Val Loss: 1783.47 (BP: 1710.10, Phys: 146.76) | Val SBP RMSE: 55.38 | Val DBP RMSE: 18.80 | Improved
# Epoch 2/50 | Train Loss: 575.97 (BP: 534.92, Phys: 82.10) | Train SBP RMSE: 30.03 | Train DBP RMSE: 12.97 | Val Loss: 264.29 (BP: 246.38, Phys: 35.81) | Val SBP RMSE: 19.44 | Val DBP RMSE: 10.71 | Improved
# Epoch 3/50 | Train Loss: 223.58 (BP: 205.75, Phys: 35.67) | Train SBP RMSE: 17.29 | Train DBP RMSE: 10.62 | Val Loss: 227.45 (BP: 209.54, Phys: 35.80) | Val SBP RMSE: 17.91 | Val DBP RMSE: 9.92 | Improved
# Epoch 25/50 | Train Loss: 112.49 (BP: 93.48, Phys: 38.02) | Train SBP RMSE: 10.57 | Train DBP RMSE: 8.67 | Val Loss: 194.33 (BP: 177.92, Phys: 32.81) | Val SBP RMSE: 16.33 | Val DBP RMSE: 9.45 | No improvement (8/10)
# Epoch 26/50 | Train Loss: 111.31 (BP: 92.33, Phys: 37.97) | Train SBP RMSE: 10.48 | Train DBP RMSE: 8.65 | Val Loss: 196.00 (BP: 179.13, Phys: 33.74) | Val SBP RMSE: 16.20 | Val DBP RMSE: 9.78 | No improvement (9/10)
# Epoch 27/50 | Train Loss: 110.32 (BP: 91.29, Phys: 38.06) | Train SBP RMSE: 10.40 | Train DBP RMSE: 8.63 | Val Loss: 195.26 (BP: 177.82, Phys: 34.89) | Val SBP RMSE: 16.24 | Val DBP RMSE: 9.59 | No improvement (10/10)
# Early stopping.

# %%
results = evaluate_model_pinn(
    model,
    test_loader,
    device
)
# Out:
# ================================
# WINDKESSEL PINN TEST RESULTS
# ================================
# SBP MAE  : 11.44 mmHg
# SBP RMSE : 16.13 mmHg
# DBP MAE  : 7.50 mmHg
# DBP RMSE : 10.09 mmHg

# %%
plot_mae(results)
# Out:
# ================================
# ABSOLUTE ERROR STATISTICS
# ================================
# SBP MAE      : 11.44 mmHg
# SBP Variance : 129.28 mmHg²
# SBP Std Dev  : 11.37 mmHg
#
# DBP MAE      : 7.50 mmHg
# DBP Variance : 45.59 mmHg²
# DBP Std Dev  : 6.75 mmHg

# %%
model = create_small_resnet1d().to(device)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-4
)

# %%
model, best_val_loss = train_model_pinn(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    RC=RC,
    device=device,
    epochs=50,
    lambda_phys=1,
    patience=10
)
# Out:
# Epoch 1/50 | Train Loss: 5990.83 (BP: 5925.13, Phys: 65.70) | Train SBP RMSE: 98.99 | Train DBP RMSE: 45.29 | Val Loss: 2484.54 (BP: 2416.38, Phys: 68.16) | Val SBP RMSE: 64.36 | Val DBP RMSE: 26.27 | Improved
# Epoch 2/50 | Train Loss: 655.70 (BP: 605.69, Phys: 50.01) | Train SBP RMSE: 31.67 | Train DBP RMSE: 14.43 | Val Loss: 268.65 (BP: 248.88, Phys: 19.77) | Val SBP RMSE: 19.45 | Val DBP RMSE: 10.94 | Improved
# Epoch 3/50 | Train Loss: 238.16 (BP: 216.69, Phys: 21.47) | Train SBP RMSE: 17.55 | Train DBP RMSE: 11.19 | Val Loss: 229.77 (BP: 211.26, Phys: 18.52) | Val SBP RMSE: 17.47 | Val DBP RMSE: 10.84 | Improved
# Epoch 4/50 | Train Loss: 217.53 (BP: 197.77, Phys: 19.76) | Train SBP RMSE: 16.58 | Train DBP RMSE: 10.99 | Val Loss: 224.72 (BP: 202.84, Phys: 21.88) | Val SBP RMSE: 17.28 | Val DBP RMSE: 10.34 | Improved
# Epoch 5/50 | Train Loss: 202.86 (BP: 183.80, Phys: 19.05) | Train SBP RMSE: 15.82 | Train DBP RMSE: 10.83 | Val Loss: 232.17 (BP: 210.99, Phys: 21.18) | Val SBP RMSE: 17.49 | Val DBP RMSE: 10.77 | No improvement (1/10)
# Epoch 6/50 | Train Loss: 191.34 (BP: 172.45, Phys: 18.88) | Train SBP RMSE: 15.18 | Train DBP RMSE: 10.69 | Val Loss: 217.80 (BP: 200.56, Phys: 17.24) | Val SBP RMSE: 17.24 | Val DBP RMSE: 10.19 | Improved
# Epoch 7/50 | Train Loss: 182.33 (BP: 163.49, Phys: 18.84) | Train SBP RMSE: 14.67 | Train DBP RMSE: 10.57 | Val Loss: 207.51 (BP: 187.98, Phys: 19.53) | Val SBP RMSE: 16.53 | Val DBP RMSE: 10.14 | Improved
# Epoch 8/50 | Train Loss: 175.41 (BP: 156.50, Phys: 18.91) | Train SBP RMSE: 14.25 | Train DBP RMSE: 10.48 | Val Loss: 210.08 (BP: 192.09, Phys: 17.98) | Val SBP RMSE: 16.54 | Val DBP RMSE: 10.52 | No improvement (1/10)
# Epoch 9/50 | Train Loss: 169.04 (BP: 150.12, Phys: 18.92) | Train SBP RMSE: 13.87 | Train DBP RMSE: 10.39 | Val Loss: 205.50 (BP: 188.55, Phys: 16.96) | Val SBP RMSE: 16.49 | Val DBP RMSE: 10.26 | Improved
# Epoch 10/50 | Train Loss: 164.06 (BP: 145.06, Phys: 18.99) | Train SBP RMSE: 13.56 | Train DBP RMSE: 10.31 | Val Loss: 213.44 (BP: 196.94, Phys: 16.49) | Val SBP RMSE: 17.02 | Val DBP RMSE: 10.21 | No improvement (1/10)
# Epoch 11/50 | Train Loss: 159.25 (BP: 140.20, Phys: 19.05) | Train SBP RMSE: 13.24 | Train DBP RMSE: 10.26 | Val Loss: 213.50 (BP: 195.95, Phys: 17.54) | Val SBP RMSE: 16.73 | Val DBP RMSE: 10.58 | No improvement (2/10)
# Epoch 12/50 | Train Loss: 155.62 (BP: 136.49, Phys: 19.13) | Train SBP RMSE: 13.00 | Train DBP RMSE: 10.20 | Val Loss: 211.20 (BP: 194.84, Phys: 16.35) | Val SBP RMSE: 16.61 | Val DBP RMSE: 10.67 | No improvement (3/10)
# Epoch 13/50 | Train Loss: 152.11 (BP: 132.92, Phys: 19.18) | Train SBP RMSE: 12.76 | Train DBP RMSE: 10.14 | Val Loss: 205.56 (BP: 189.35, Phys: 16.21) | Val SBP RMSE: 16.45 | Val DBP RMSE: 10.40 | No improvement (4/10)
# Epoch 14/50 | Train Loss: 148.84 (BP: 129.60, Phys: 19.23) | Train SBP RMSE: 12.54 | Train DBP RMSE: 10.10 | Val Loss: 216.16 (BP: 198.15, Phys: 18.01) | Val SBP RMSE: 16.82 | Val DBP RMSE: 10.65 | No improvement (5/10)
# Epoch 15/50 | Train Loss: 146.09 (BP: 126.87, Phys: 19.22) | Train SBP RMSE: 12.35 | Train DBP RMSE: 10.06 | Val Loss: 209.25 (BP: 192.11, Phys: 17.14) | Val SBP RMSE: 16.53 | Val DBP RMSE: 10.53 | No improvement (6/10)
# Epoch 16/50 | Train Loss: 143.64 (BP: 124.40, Phys: 19.24) | Train SBP RMSE: 12.17 | Train DBP RMSE: 10.03 | Val Loss: 216.89 (BP: 198.13, Phys: 18.77) | Val SBP RMSE: 16.68 | Val DBP RMSE: 10.86 | No improvement (7/10)
# Epoch 17/50 | Train Loss: 141.08 (BP: 121.80, Phys: 19.27) | Train SBP RMSE: 12.00 | Train DBP RMSE: 9.98 | Val Loss: 202.02 (BP: 183.39, Phys: 18.63) | Val SBP RMSE: 16.14 | Val DBP RMSE: 10.30 | Improved
# Epoch 18/50 | Train Loss: 139.12 (BP: 119.84, Phys: 19.28) | Train SBP RMSE: 11.85 | Train DBP RMSE: 9.96 | Val Loss: 201.72 (BP: 183.73, Phys: 18.00) | Val SBP RMSE: 16.24 | Val DBP RMSE: 10.19 | Improved
# Epoch 19/50 | Train Loss: 137.37 (BP: 118.02, Phys: 19.36) | Train SBP RMSE: 11.72 | Train DBP RMSE: 9.93 | Val Loss: 200.84 (BP: 182.64, Phys: 18.20) | Val SBP RMSE: 16.11 | Val DBP RMSE: 10.28 | Improved
# Epoch 20/50 | Train Loss: 135.56 (BP: 116.21, Phys: 19.35) | Train SBP RMSE: 11.59 | Train DBP RMSE: 9.90 | Val Loss: 203.55 (BP: 184.84, Phys: 18.71) | Val SBP RMSE: 16.32 | Val DBP RMSE: 10.17 | No improvement (1/10)
# Epoch 21/50 | Train Loss: 133.99 (BP: 114.62, Phys: 19.37) | Train SBP RMSE: 11.48 | Train DBP RMSE: 9.87 | Val Loss: 214.61 (BP: 193.93, Phys: 20.68) | Val SBP RMSE: 16.75 | Val DBP RMSE: 10.36 | No improvement (2/10)
# Epoch 22/50 | Train Loss: 132.63 (BP: 113.26, Phys: 19.37) | Train SBP RMSE: 11.38 | Train DBP RMSE: 9.85 | Val Loss: 204.46 (BP: 185.25, Phys: 19.21) | Val SBP RMSE: 16.31 | Val DBP RMSE: 10.22 | No improvement (3/10)
# Epoch 23/50 | Train Loss: 131.01 (BP: 111.67, Phys: 19.35) | Train SBP RMSE: 11.26 | Train DBP RMSE: 9.83 | Val Loss: 202.37 (BP: 186.12, Phys: 16.26) | Val SBP RMSE: 16.41 | Val DBP RMSE: 10.14 | No improvement (4/10)
# Epoch 24/50 | Train Loss: 129.93 (BP: 110.54, Phys: 19.38) | Train SBP RMSE: 11.18 | Train DBP RMSE: 9.81 | Val Loss: 198.06 (BP: 180.88, Phys: 17.18) | Val SBP RMSE: 15.96 | Val DBP RMSE: 10.34 | Improved
# Epoch 25/50 | Train Loss: 128.80 (BP: 109.40, Phys: 19.40) | Train SBP RMSE: 11.09 | Train DBP RMSE: 9.78 | Val Loss: 207.88 (BP: 191.40, Phys: 16.48) | Val SBP RMSE: 16.65 | Val DBP RMSE: 10.28 | No improvement (1/10)
# Epoch 26/50 | Train Loss: 127.37 (BP: 107.98, Phys: 19.39) | Train SBP RMSE: 10.98 | Train DBP RMSE: 9.76 | Val Loss: 208.14 (BP: 189.54, Phys: 18.60) | Val SBP RMSE: 16.36 | Val DBP RMSE: 10.56 | No improvement (2/10)
# Epoch 27/50 | Train Loss: 126.91 (BP: 107.47, Phys: 19.43) | Train SBP RMSE: 10.95 | Train DBP RMSE: 9.75 | Val Loss: 193.80 (BP: 176.65, Phys: 17.15) | Val SBP RMSE: 15.76 | Val DBP RMSE: 10.25 | Improved
# Epoch 28/50 | Train Loss: 125.92 (BP: 106.57, Phys: 19.35) | Train SBP RMSE: 10.87 | Train DBP RMSE: 9.75 | Val Loss: 203.07 (BP: 183.97, Phys: 19.10) | Val SBP RMSE: 16.20 | Val DBP RMSE: 10.27 | No improvement (1/10)
# Epoch 29/50 | Train Loss: 125.14 (BP: 105.76, Phys: 19.38) | Train SBP RMSE: 10.82 | Train DBP RMSE: 9.72 | Val Loss: 194.84 (BP: 177.21, Phys: 17.62) | Val SBP RMSE: 15.83 | Val DBP RMSE: 10.19 | No improvement (2/10)
# Epoch 30/50 | Train Loss: 124.02 (BP: 104.65, Phys: 19.37) | Train SBP RMSE: 10.73 | Train DBP RMSE: 9.70 | Val Loss: 204.16 (BP: 185.79, Phys: 18.38) | Val SBP RMSE: 16.34 | Val DBP RMSE: 10.22 | No improvement (3/10)
# Epoch 31/50 | Train Loss: 123.35 (BP: 103.95, Phys: 19.40) | Train SBP RMSE: 10.68 | Train DBP RMSE: 9.68 | Val Loss: 205.40 (BP: 186.31, Phys: 19.09) | Val SBP RMSE: 16.13 | Val DBP RMSE: 10.61 | No improvement (4/10)
# Epoch 32/50 | Train Loss: 122.43 (BP: 103.14, Phys: 19.29) | Train SBP RMSE: 10.61 | Train DBP RMSE: 9.68 | Val Loss: 201.73 (BP: 182.63, Phys: 19.10) | Val SBP RMSE: 16.12 | Val DBP RMSE: 10.27 | No improvement (5/10)
# Epoch 33/50 | Train Loss: 121.64 (BP: 102.28, Phys: 19.36) | Train SBP RMSE: 10.55 | Train DBP RMSE: 9.65 | Val Loss: 198.64 (BP: 179.95, Phys: 18.69) | Val SBP RMSE: 16.04 | Val DBP RMSE: 10.14 | No improvement (6/10)
# Epoch 34/50 | Train Loss: 121.22 (BP: 101.87, Phys: 19.36) | Train SBP RMSE: 10.52 | Train DBP RMSE: 9.64 | Val Loss: 201.98 (BP: 184.03, Phys: 17.94) | Val SBP RMSE: 16.28 | Val DBP RMSE: 10.16 | No improvement (7/10)
# Epoch 35/50 | Train Loss: 120.61 (BP: 101.26, Phys: 19.35) | Train SBP RMSE: 10.48 | Train DBP RMSE: 9.63 | Val Loss: 197.05 (BP: 177.24, Phys: 19.81) | Val SBP RMSE: 15.80 | Val DBP RMSE: 10.24 | No improvement (8/10)
# Epoch 36/50 | Train Loss: 119.96 (BP: 100.59, Phys: 19.37) | Train SBP RMSE: 10.42 | Train DBP RMSE: 9.62 | Val Loss: 199.92 (BP: 181.98, Phys: 17.94) | Val SBP RMSE: 16.12 | Val DBP RMSE: 10.20 | No improvement (9/10)
# Epoch 37/50 | Train Loss: 119.32 (BP: 99.97, Phys: 19.35) | Train SBP RMSE: 10.37 | Train DBP RMSE: 9.61 | Val Loss: 199.38 (BP: 180.12, Phys: 19.26) | Val SBP RMSE: 16.03 | Val DBP RMSE: 10.17 | No improvement (10/10)
# Early stopping.

# %%
results = evaluate_model_pinn(
    model,
    test_loader,
    device
)
# Out:
# ================================
# WINDKESSEL PINN TEST RESULTS
# ================================
# SBP MAE  : 11.03 mmHg
# SBP RMSE : 15.65 mmHg
# DBP MAE  : 8.08 mmHg
# DBP RMSE : 10.71 mmHg

# %%
plot_mae(results)
# Out:
# ================================
# ABSOLUTE ERROR STATISTICS
# ================================
# SBP MAE      : 11.03 mmHg
# SBP Variance : 123.14 mmHg²
# SBP Std Dev  : 11.10 mmHg
#
# DBP MAE      : 8.08 mmHg
# DBP Variance : 49.39 mmHg²
# DBP Std Dev  : 7.03 mmHg
